# %% [markdown]
# # Import and Constants

# %%
# Import

import simpy
from simpy.events import AnyOf
import numpy as np
from numpy import random
import pandas as pd

import statistics
import matplotlib.pyplot as plt

from scipy.stats import t

# %%
# Constants

AMOUNT_OF_PRODUCTS = 4

a = 0.05

MACHINE_TIME_IO = 1.05
MACHINE_TIME_AGENT_1 = 0.001
MACHINE_TIME_UP_1 = 2.05
MACHINE_TIME_DOWN_1 = 1.05
MACHINE_TIME_UP_2 = 6.05
MACHINE_TIME_DOWN_2 = 10.05
MACHINE_TIME_QUALITY = 1.05

machine_time_io = lambda: random.uniform(MACHINE_TIME_IO-a,MACHINE_TIME_IO+a)
machine_time_up_1 = lambda: random.exponential(MACHINE_TIME_UP_1)#-a,MACHINE_TIME_UP_1+a)
machine_time_down_1 = lambda: random.exponential(MACHINE_TIME_DOWN_1)#-a,MACHINE_TIME_DOWN_1+a)
machine_time_up_2 = lambda: random.exponential(MACHINE_TIME_UP_2)#-a,MACHINE_TIME_UP_2+a)
machine_time_down_2 = lambda: random.exponential(MACHINE_TIME_DOWN_2)#-a,MACHINE_TIME_DOWN_2+a)
machine_time_quality = lambda: random.uniform(MACHINE_TIME_QUALITY-a,MACHINE_TIME_QUALITY+a)

TRANSPORT_TIME_IO_AGENT_1 = 1.05
TRANSPORT_TIME_AGENT_1_UP_1 = 1.05
TRANSPORT_TIME_AGENT_1_DOWN_1 = 1.05
TRANSPORT_TIME_UP_1_UP_2 = 1.05
TRANSPORT_TIME_DOWN_1_DOWN_2 = 1.05

TRANSPORT_TIME_UP_2_QUALITY = 1.05
TRANSPORT_TIME_DOWN_2_QUALITY = 1.05

TRANSPORT_TIME_QUALITY_IO = 1.05

transport_time_io_agent_1 = lambda: random.uniform(TRANSPORT_TIME_IO_AGENT_1-a,TRANSPORT_TIME_IO_AGENT_1+a)
transport_time_agent_1_up_1 = lambda: random.uniform(TRANSPORT_TIME_AGENT_1_UP_1-a,TRANSPORT_TIME_AGENT_1_UP_1+a)
transport_time_agent_1_down_1 = lambda: random.uniform(TRANSPORT_TIME_AGENT_1_DOWN_1-a,TRANSPORT_TIME_AGENT_1_DOWN_1+a)
transport_time_up_1_up_2 = lambda: random.uniform(TRANSPORT_TIME_UP_1_UP_2-a,TRANSPORT_TIME_UP_1_UP_2+a)
transport_time_down_1_down_2 = lambda: random.uniform(TRANSPORT_TIME_DOWN_1_DOWN_2-a,TRANSPORT_TIME_DOWN_1_DOWN_2+a)

transport_time_up_2_quality = lambda: random.uniform(TRANSPORT_TIME_UP_2_QUALITY-a,TRANSPORT_TIME_UP_2_QUALITY+a)
transport_time_down_2_quality = lambda: random.uniform(TRANSPORT_TIME_DOWN_2_QUALITY-a,TRANSPORT_TIME_DOWN_2_QUALITY+a)

transport_time_quality_io = lambda: random.uniform(TRANSPORT_TIME_QUALITY_IO-a,TRANSPORT_TIME_QUALITY_IO+a)

SOURCE_TIME = 1

SEED_PALLET = 42

CAP_BUF_IO = AMOUNT_OF_PRODUCTS
CAP_BUF_AGENT_1 = AMOUNT_OF_PRODUCTS
CAP_BUF_UP_1 = AMOUNT_OF_PRODUCTS
CAP_BUF_DOWN_1 = AMOUNT_OF_PRODUCTS
CAP_BUF_UP_2 = AMOUNT_OF_PRODUCTS
CAP_BUF_DOWN_2 = AMOUNT_OF_PRODUCTS
CAP_BUF_QUALITY = AMOUNT_OF_PRODUCTS

SIMULATION_LENGTH = 200000
NUM_PALLET = 10000000
NUM_AGENT = 1

T_STEP = 0.999764/2
T_START = AMOUNT_OF_PRODUCTS + 0.5
IO_LAG = 0.0001
JUNCTION_LAG = 0.0001

M = 1000
OCC = 10
TH_P = 1000
STEP = 10

PALLET_STAR = 1
seed_list = [1, 2, 3, 4, 5]

# %% [markdown]
# # Simulation Functions

# %%
# Pallets

sequences = ['1234']

class Pallet:
    def __init__(self, sequence, next_ope, pallet, product):
        self.sequence = sequence
        self.next_ope = next_ope
        self.pallet = pallet
        self.product = product
        
    def __repr__(self):
        return (f"Pallet {self.pallet} carrying Product {self.product} with sequence {self.sequence}, next operation: {self.sequence[self.next_ope]}")

random.seed(SEED_PALLET)

Pallets_List = []
for i in range(NUM_PALLET):
    p = Pallet('1234', 0, 0, i+1) #sequences[random.randint(0,len(sequences)-1)]
    Pallets_List.append(p)

# %%
# Environments

def create_environment():

    env = simpy.Environment()

    resources = {
        'env': env,

        'machine_io': simpy.Resource(env, capacity=1),
        'machine_agent_1': simpy.Resource(env, capacity=1),
        'machine_up_1': simpy.Resource(env, capacity=1),
        'machine_down_1': simpy.Resource(env, capacity=1),
        'machine_up_2': simpy.Resource(env, capacity=1),
        'machine_down_2': simpy.Resource(env, capacity=1),
        'machine_quality': simpy.Resource(env, capacity=1),

        'machine_io_s': simpy.Resource(env, capacity=1),
        'machine_up_1_s': simpy.Resource(env, capacity=1),
        'machine_down_1_s': simpy.Resource(env, capacity=1),
        'machine_up_2_s': simpy.Resource(env, capacity=1),
        'machine_down_2_s': simpy.Resource(env, capacity=1),
        'machine_quality_s': simpy.Resource(env, capacity=1),        

        'buffer_io': simpy.FilterStore(env, capacity=CAP_BUF_IO),
        'buffer_agent_1': simpy.FilterStore(env, capacity=CAP_BUF_AGENT_1),
        'buffer_up_1': simpy.FilterStore(env, capacity=CAP_BUF_UP_1),
        'buffer_down_1': simpy.FilterStore(env, capacity=CAP_BUF_DOWN_1),
        'buffer_up_2': simpy.FilterStore(env, capacity=CAP_BUF_UP_2),
        'buffer_down_2': simpy.FilterStore(env, capacity=CAP_BUF_DOWN_2),
        'buffer_quality': simpy.FilterStore(env, capacity=CAP_BUF_QUALITY),   

        'check_buf_io': env.event(),

        'check_agent_1_in': env.event(),
        'check_agent_1_out': env.event(),
        'check_agent_1_blocking': env.event(),

        'check_buf_up_1': env.event(),
        'check_buf_down_1': env.event(),

        'check_buf_up_2': env.event(),
        'check_buf_down_2': env.event(),

        'check_junction_1': env.event(),

        'check_agent_2_in': env.event(),
        'check_agent_2_out': env.event(),
        'check_agent_2_blocking': env.event(),

        'check_buf_quality': env.event(),
        'check_production_event': env.event(),

        'container_quality': simpy.Container(env, capacity=CAP_BUF_QUALITY+1, init=CAP_BUF_QUALITY+1),

        'containers_list': ['quality'],
        'container_quality_list': [],

        'q_enter': 0,
        't_enter': 0,
        'flow': 0,
        'flow_time': [],
        'j': AMOUNT_OF_PRODUCTS,
        'th': 0, 
        'th_1': 0,
        'pr_count': 0
        }

    return env, resources

machines_list = ['io', 'up_1', 'down_1', 'up_2', 'down_2', 'quality']

machine_up_1_op = ['1']
machine_down_1_op = ['1']
machine_up_2_op = ['2']
machine_down_2_op = ['2']
machine_quality_op = ['3']
machine_io_op = ['4']

all_op = set()
for machine in machines_list:
    ops = globals()[f'machine_{machine}_op']
    all_op.update(ops)
all_op = list(all_op)

# %%
# Production Functions (without Prints)

def normal_production_stage(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users)!= res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def normal_io(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f"{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n")

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_stage_before_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
            
            config['check_event'].succeed(); config['check_event'] = env.event()
            
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield container_out.get(1)    
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users)!= res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)

    container_out_list.append(pallet)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)

    if pallet.pallet == PALLET_STAR:
        res[config['th']] = 1
        config['config_agent']['check_junction'].succeed(); config['config_agent']['check_junction'] = env.event()
        yield env.timeout(JUNCTION_LAG)
        res[config['th']] = 0

    del container_out_list[0]
    yield buffer_out.put(pallet)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def io_before_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f"{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n")

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield container_out.get(1)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)

    container_out_list.append(pallet)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    del container_out_list[0]
    yield buffer_out.put(pallet)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_stage_after_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    yield container_in.put(1)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def io_after_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f"{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n")

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    yield container_in.put(1)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_stage_between_junctions(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield container_out.get(1)    
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)
    
    container_out_list.append(pallet)
    yield container_in.put(1)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    del container_out_list[0]
    yield buffer_out.put(pallet)

    env.process(next_process_func(env, res, pallet, next_config, f, train))

def io_between_junctions(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f"{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n")

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield container_out.get(1)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)

    container_out_list.append(pallet)
    yield container_in.put(1)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    del container_out_list[0]
    yield buffer_out.put(pallet)
    
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_agent_RL(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    agent = config['agent']
    mode = config['mode']
    actions = config['actions']
    container_in = config['container_in']
    event_in = config['check_agent_in']
    event_out = config['check_agent_out']
    event_blocking = config['check_agent_blocking']
    variables = config['variables']
    target_positions = config['target_positions']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)

        if pallet.pallet == PALLET_STAR:
            res['t_enter'] = env.now

        if not train and machine_agent == res['machine_agent_1']:
            f.write(f"{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n")

        state = get_state(env, res, PALLET_STAR)

        if mode == 'train' and pallet.pallet == PALLET_STAR:
            reduced_state = reduce_state_train(state, variables, target_positions)
        else:
            reduced_state = reduce_state_test(state, variables)

        yield env.timeout(machine_time_agent)

        if mode == 'train' and pallet.pallet == PALLET_STAR:
            agent_decision = agent.choose_action_train(reduced_state)
        if mode == 'train' and pallet.pallet != PALLET_STAR:
            agent_decision = agent.choose_action_test(reduced_state) 
        if mode == 'test':
            agent_decision = agent.choose_action_test(reduced_state)

        action_config = actions[agent_decision]
        reward = 0
        blocking = 0

        if mode == 'train' and pallet.pallet == PALLET_STAR:
            if 'requires_container_out' in action_config:
                if action_config['container_out'].level == 0:
                    blocking = 1
                    new_state = get_state(env, res, PALLET_STAR)
                    new_reduced_state = reduce_state_train(new_state, variables, target_positions)
                    agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state)
                    config['check_agent_out'].succeed(); config['check_agent_out'] = env.event()
            else:
                if len(action_config['buffer_out'].items) == action_config['buffer_out'].capacity:
                    blocking = 1                        
                    new_state = get_state(env, res, PALLET_STAR)
                    new_reduced_state = reduce_state_train(new_state, variables, target_positions)
                    agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state)
                    config['check_agent_out'].succeed(); config['check_agent_out'] = env.event()

        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)        
    
    if mode == 'train' and pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['flow'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

        if blocking == 0:
            new_state = get_state(env, res, PALLET_STAR)
            new_reduced_state = reduce_state_train(new_state, variables, target_positions)
            
            agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state)
            config['check_agent_out'].succeed(); config['check_agent_out'] = env.event()

    if container_in:
        yield container_in.put(1)
    
    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)

    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

def production_agent_random(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    actions = config['actions'] 
    container_in = config['container_in']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)

        if machine_agent == res['machine_agent_1']:
            f.write(f"{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n")
        yield env.timeout(machine_time_agent)
        agent_decision = random.choice(list(config['actions'].keys()))
        action_config = actions[agent_decision]

        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['flow'] = env.now

    if container_in:
        yield container_in.put(1)

    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)
        
    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

def production_agent_heuristic_th(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    actions = config['actions'] 
    container_in = config['container_in']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)

        if machine_agent == res['machine_agent_1']:
            f.write(f"{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n")
        yield env.timeout(machine_time_agent)

        buffer_counts = {
            action: len(actions[action]['buffer_out'].items)
            for action in actions
        }

        min_count = min(buffer_counts.values())

        candidates = [action for action, count in buffer_counts.items() if count == min_count]

        for preferred_action in config['priority']:
            if preferred_action in candidates:
                agent_decision = preferred_action
                break

        action_config = actions[agent_decision]

        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['flow'] = env.now

    if container_in:
        yield container_in.put(1)

    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)

    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

def production_agent_heuristic_flow(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    actions = config['actions'] 
    container_in = config['container_in']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)

        if machine_agent == res['machine_agent_1']:
            f.write(f"{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n")
        yield env.timeout(machine_time_agent)

        best_action = None
        min_value = float('inf')

        for direction, values in actions.items():
            buffer_len = len(values['buffer_bottleneck'].items)
            machine_users = len(values['machine_bottleneck'].users)
            machine_time = values['machine_time_bottleneck']
    
            value = (1 + buffer_len + machine_users) * machine_time
    
            if value < min_value:
                min_value = value
                best_action = direction

        agent_decision = best_action

        action_config = actions[agent_decision]

        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['flow'] = env.now

    if container_in:
        yield container_in.put(1)

    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)

    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

# %%
# Get State Function

def get_state(env, res, pallet):

    ag1 = 0
    next_ope_1 = '0'
    pos = '0'
    queue = 0
    slot = 0
    time = env.now - res['t_enter']
    th_pr = res['th']
    th_1 = res['th_1']
    buf_ag1 = 0

    if res['machine_agent_1'].users:
        ag1 = 1
        next_ope_1 = res['machine_agent_1'].users[0].pallet.sequence[res['machine_agent_1'].users[0].pallet.next_ope]
        if res['machine_agent_1'].users[0].pallet.pallet == pallet:
            pos = "machine_agent_1"
            queue = 0

    if res['buffer_agent_1'].items:
        for idx, item in enumerate(res['buffer_agent_1'].items):
            buf_ag1 += 1
            if item.pallet == pallet:
                pos = 'buffer_agent_1'
                queue = idx+1 if res['machine_agent_1'].users else idx 

    counters = {}

    all_op = set()
    for machine in machines_list:
        name = str(machine)
        op_list = globals()[f"machine_{name}_op"]
        all_op.update(op_list)
    all_op = list(all_op)

    for machine in machines_list:
        name = str(machine)
        op_list = globals()[f"machine_{name}_op"]
        not_handled_ops = set(all_op) - set(op_list)

        counters[name] = 0
        for op in not_handled_ops:
            counters[f"{name}_s{op}"] = 0

        buffer = res[f"buffer_{name}"]
        machine_obj = res[f"machine_{name}"]

        for idx, item in enumerate(buffer.items):
            next_op = item.sequence[item.next_ope]
            if next_op in op_list:
                counters[name] += 1
                if item.pallet == pallet:
                    pos = f"machine_{name}"
                    queue = idx+1 if machine_obj.users else idx
            elif next_op in not_handled_ops:
                counters[f"{name}_s{next_op}"] += 1
                machine_obj_s = res[f"machine_{name}_s"]
                if item.pallet == pallet:
                    pos = f"machine_{name}_s{next_op}"
                    queue = idx+1 if machine_obj_s.users else idx

        if machine_obj.users:
            if machine_obj.users[0].pallet.pallet == pallet:
                pos = f"machine_{name}"
                queue = 0
            counters[name] += 1

        machine_s = res.get(f"machine_{name}_s")
        if machine_s and machine_s.users:
            next_op_s = machine_s.users[0].pallet.sequence[machine_s.users[0].pallet.next_ope] ## FIX!
            if machine_s.users[0].pallet.pallet == pallet:
                pos = f"machine_{name}_s{next_op_s}"
                queue = 0
            counters[f"{name}_s{next_op_s}"] += 1

        if name in res['containers_list']:
            container_pals = res.get(f"container_{name}_list", [])
            buffer = res[f"buffer_{name}"]
            for idx, container_pal in enumerate(container_pals):
                if container_pal.sequence[container_pal.next_ope] in op_list:
                    counters[name] += 1
                    if container_pal.pallet == pallet:
                        pos =  f"machine_{name}"
                        queue = idx+len(buffer.items)+1 if machine_obj.users else idx+len(buffer.items)
                else:
                    counters[f"{name}_s{container_pal.sequence[container_pal.next_ope]}"] += 1
                    if container_pal.pallet == pallet:
                        pos = f"machine_{name}_s{container_pal.sequence[container_pal.next_ope]}"
                        queue = idx+len(buffer.items)+1 if machine_obj.users else idx+len(buffer.items)

    slot = round(time/5)
    
    state = {
        "ag_1": ag1,
        "next_ope_1": next_ope_1,
        "pos": pos,
        "slot": slot,
        "queue": queue,
        **counters,
        "th_pr": th_pr,
        "buf_ag_1": buf_ag1,
        'th_1': th_1,
    }

    return state

def state_to_tuple(state_dict):
    return tuple(state_dict.items())

# %%
# Configs

def create_configs(res, agent_function_1):
    global config_io, config_agent_1, config_up_1, config_down_1, config_up_2, config_down_2, config_quality
    
    config_io = {
        'check_event': res['check_buf_io'],
        'buffer_in': res['buffer_io'],
        'buffer_out': res['buffer_agent_1'],
        'machine': res['machine_io'],
        'machine_s': res['machine_io_s'],
        'machine_ops': machine_io_op,
        'machine_time': machine_time_io,
        'transport_time': transport_time_io_agent_1,
        'io_lag': IO_LAG,
        'name': 'I/O',
        'next_process_func': agent_function_1,
        'next_config': None,
        'check_production_event': res['check_production_event']
    }

    config_agent_1 = {
        'machine_agent': res['machine_agent_1'],
        'buffer_agent': res['buffer_agent_1'],
        'machine_time_agent': MACHINE_TIME_AGENT_1,
        'actions': {
            'up': {
                'transport_time': transport_time_agent_1_up_1,
                'buffer_out': res['buffer_up_1'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_up_2'],
                'machine_time_bottleneck': MACHINE_TIME_UP_2,
                'buffer_bottleneck': res['buffer_up_2']
            },
            'down': {
                'transport_time': transport_time_agent_1_down_1,
                'buffer_out': res['buffer_down_1'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_down_2'],
                'machine_time_bottleneck': MACHINE_TIME_DOWN_2,
                'buffer_bottleneck': res['buffer_down_2']
            },
        },
        'container_in': None,
        'priority': ['down', 'up'],
        'check_junction': res['check_junction_1'],
    }

    config_up_1 = {
        'check_event': res['check_buf_up_1'],
        'buffer_in': res['buffer_up_1'],
        'buffer_out': res['buffer_up_2'],
        'machine': res['machine_up_1'],
        'machine_s': res['machine_up_1_s'],
        'machine_ops': machine_up_1_op,
        'machine_time': machine_time_up_1,
        'transport_time': transport_time_up_1_up_2,
        'name': 'UP1',
        'next_process_func': production_stage_before_junction,
        'next_config': None,
    }

    config_down_1 = {
        'check_event': res['check_buf_down_1'],
        'buffer_in': res['buffer_down_1'],
        'buffer_out': res['buffer_down_2'],
        'machine': res['machine_down_1'],
        'machine_s': res['machine_down_1_s'],
        'machine_ops': machine_down_1_op,
        'machine_time': machine_time_down_1,
        'transport_time': transport_time_down_1_down_2,
        'name': 'DOWN1',
        'next_process_func': production_stage_before_junction,
        'next_config': None,
    }

    config_up_2 = {
        'check_event': res['check_buf_up_2'],
        'buffer_in': res['buffer_up_2'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_up_2'],
        'machine_s': res['machine_up_2_s'],
        'machine_ops': machine_up_2_op,
        'machine_time': machine_time_up_2,
        'transport_time': transport_time_up_2_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': 'UP2',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': res['th_1'],
        'config_agent': None
    }

    config_down_2 = {
        'check_event': res['check_buf_down_2'],
        'buffer_in': res['buffer_down_2'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_down_2'],
        'machine_s': res['machine_down_2_s'],
        'machine_ops': machine_down_2_op,
        'machine_time': machine_time_down_2,
        'transport_time': transport_time_down_2_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': 'DOWN2',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': res['th_1'],
        'check_junction_event': res['check_junction_1'],
        'config_agent': None
    }

    config_quality = {
        'check_event': res['check_buf_quality'],
        'buffer_in': res['buffer_quality'],
        'buffer_out': res['buffer_io'],
        'machine': res['machine_quality'],
        'machine_s': res['machine_quality_s'],
        'machine_ops': machine_quality_op,
        'machine_time': machine_time_quality,
        'transport_time': transport_time_quality_io,
        'container_in': res['container_quality'],
        'container_in_list': res['container_quality_list'],
        'name': 'QUALITY',
        'next_process_func': normal_io,
        'next_config': None,
    }

    config_io['next_config'] = config_agent_1

    config_agent_1['actions']['up']['next_config'] = config_up_1
    config_agent_1['actions']['down']['next_config'] = config_down_1

    config_up_1['next_config'] = config_up_2
    config_down_1['next_config'] = config_down_2

    config_up_2['next_config'] = config_quality
    config_up_2['config_agent'] = config_agent_1
    config_down_2['next_config'] = config_quality
    config_down_2['config_agent'] = config_agent_1

    config_quality['next_config'] = config_io

# %%
# Source

def source(env, res, agent_function_1, file):
    for i in range(AMOUNT_OF_PRODUCTS):
        t_source = SOURCE_TIME
        yield env.timeout(t_source)
        pallet_type = Pallets_List[i]
        pallet_type.pallet = i+1
        pallet_type.next_ope = 0
        yield res['buffer_agent_1'].put(pallet_type)
        que_agent = agent_function_1(env, res, pallet_type, config_agent_1, file)
        env.process(que_agent)

# %% [markdown]
# # Random Policy

# %%
# Process and Run

counts_random = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs(resources, production_agent_random)
    log_filename = f"RandomPolicy_{seed}.txt"
    f = open(log_filename, "w")
    env.process(source(env, resources, production_agent_random, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_random.append(resources['pr_count'])
    print('Total Production of Random Policy: ', resources['pr_count'])
# Out:
# Total Production of Random Policy:  31917
# Total Production of Random Policy:  32343
# Total Production of Random Policy:  32390
# Total Production of Random Policy:  32365
# Total Production of Random Policy:  32409

# %% [markdown]
# # Heuristic Policy Th

# %%
# Process and Run

counts_heuristic_th = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs(resources, production_agent_heuristic_th)
    log_filename = f"HeuristicPolicyTh_{seed}.txt"
    f = open(log_filename, "w")
    env.process(source(env, resources, production_agent_heuristic_th, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_heuristic_th.append(resources['pr_count'])
    print('Total Production of Heuristic (for Throughput) Policy: ', resources['pr_count'])
# Out:
# Total Production of Heuristic (for Throughput) Policy:  20647
# Total Production of Heuristic (for Throughput) Policy:  20725
# Total Production of Heuristic (for Throughput) Policy:  20422
# Total Production of Heuristic (for Throughput) Policy:  20801
# Total Production of Heuristic (for Throughput) Policy:  20586

# %% [markdown]
# # Heuristic Policy Flow

# %%
# Process and Run

counts_heuristic_flow = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs(resources, production_agent_heuristic_flow)
    log_filename = f"HeuristicPolicyFlow_{seed}.txt"
    f = open(log_filename, "w")
    env.process(source(env, resources, production_agent_heuristic_flow, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_heuristic_flow.append(resources['pr_count'])
    print('Total Production of Heuristic (for Flow) Policy: ', resources['pr_count'])
# Out:
# Total Production of Heuristic (for Flow) Policy:  38676
# Total Production of Heuristic (for Flow) Policy:  38439
# Total Production of Heuristic (for Flow) Policy:  38039
# Total Production of Heuristic (for Flow) Policy:  38325
# Total Production of Heuristic (for Flow) Policy:  38231

# %% [markdown]
# # RL Agent

# %%
# Q-Table Print Functions

def print_q_table(agent):
    print("Q-table:")
    for (state_key, action), q_value in agent.q_table.items():
        state_dict = dict(state_key)
        if agent == agent1:
            state_dict['next_ope_1'] = str(state_dict['next_ope_1'])
        else:
            state_dict['next_ope_2'] = str(state_dict['next_ope_2'])
        state_str = ', '.join([
            f"{k}=\'{v}\'" if k == 'next_ope' else f"{k}={v}"
            for k, v in state_dict.items()
        ])
        print(f"State: ({state_str}), Action: {action} -> Q-value: {q_value:.4f}")

def print_sorted_q_table(agent):
    from collections import defaultdict
    grouped_q = defaultdict(list)

    for (state_key, action), q_value in agent.q_table.items():
        grouped_q[state_key].append((action, q_value))

    sorted_states = sorted(grouped_q.keys(), key=lambda x: tuple((k, str(v)) for k, v in sorted(x)))

    print("Sorted Q-table:")
    for state_key in sorted_states:
        state_dict = dict(state_key)

        if agent == agent1:
            state_dict['next_ope_1'] = f"\'{state_dict['next_ope_1']}\'"
        else:
            state_dict['next_ope_2'] = f"\'{state_dict['next_ope_2']}\'"

        state_str = ', '.join([
            f"{k}={v}" for k, v in state_dict.items()
        ])
        print(f"\nState: ({state_str})")

        for action, q_value in sorted(grouped_q[state_key], key=lambda x: x[0]):
            print(f"  Action: {action} -> Q-value: {q_value:.4f}")

# %%
# Agent Function

class QLearningAgent:
    def __init__(self, actions, name, alpha=0.4, gamma=0.99, epsilon=0.1):
        self.q_table = {}
        self.actions = actions
        self.actions_dense = ['wait']
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.name = name
        self.pos = 'machine_' + self.name.replace('ag_', 'agent_')

    def step_dense(self, new_state, perc):
        reward = TH_P*new_state['th_pr'] - perc*STEP
        return reward

    def choose_action_train(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(self.actions)
        state_key = state_to_tuple(state)
        q_values = [(a, self.q_table.get((state_key, a), 0)) for a in self.actions]
        max_value = max(q_values, key=lambda x: x[1])[1]
        best_actions = [a for a, v in q_values if v == max_value]
        return random.choice(best_actions)

    def choose_action_test(self, state, p=False):
        adjusted_state = dict(state)
        adjusted_state['pos'] = self.pos
        adjusted_state['queue'] = 0
        adjusted_state['slot'] = 0

        if p == True:
            print('Stato Agente Ridotto:', adjusted_state)

        state_key = state_to_tuple(adjusted_state)
        q_values = [(a, self.q_table.get((state_key, a), 0)) for a in self.actions]
        max_value = max(q_values, key=lambda x: x[1])[1]
        best_actions = [a for a, v in q_values if v == max_value]
        
        if p == True:
            print('Azione', self.name, ':', best_actions)

        return random.choice(best_actions)

    def update_agent(self, state, action, reward, new_state):
        state_key = state_to_tuple(state)
        new_state_key = state_to_tuple(new_state)
        q_predict = self.q_table.get((state_key, action), 0)
        q_target = reward + self.gamma * self.q_table.get((new_state_key, 'wait'), 0)
        self.q_table[(state_key, action)] = q_predict + self.alpha * (q_target - q_predict)

# %%
# Reduced State Function

def reduce_state_train(state, variables, target_positions):

    mandatory_vars = ['pos', 'queue', 'slot']
    variables = list(set(variables) | set(mandatory_vars))
    
    state_reduced = {k: state[k] for k in variables if k in state}

    if state_reduced['pos'] not in target_positions:
        state_reduced = {k: 0 for k in state_reduced}
        
    return state_reduced

def reduce_state_test(state, variables):

    mandatory_vars = ['pos', 'queue', 'slot']
    variables = list(set(variables) | set(mandatory_vars))
    
    state_reduced = {k: state[k] for k in variables if k in state}

    return state_reduced

# %%
# Configs

def create_configs_RL(res, agent1, mode):
    global config_io, config_agent_1, config_up_1, config_down_1, config_up_2, config_down_2, config_quality
    
    config_io = {
        'check_event': res['check_buf_io'],
        'buffer_in': res['buffer_io'],
        'buffer_out': res['buffer_agent_1'],
        'machine': res['machine_io'],
        'machine_s': res['machine_io_s'],
        'machine_ops': machine_io_op,
        'machine_time': machine_time_io,
        'transport_time': transport_time_io_agent_1,
        'io_lag': IO_LAG,
        'name': 'I/O',
        'next_process_func': production_agent_RL,
        'next_config': None,
        'check_production_event': res['check_production_event']
    }

    config_agent_1 = {
        'machine_agent': res['machine_agent_1'],
        'buffer_agent': res['buffer_agent_1'],
        'machine_time_agent': MACHINE_TIME_AGENT_1,
        'agent': agent1,
        'mode': mode,
        'actions': {
            'up': {
                'transport_time': transport_time_agent_1_up_1,
                'buffer_out': res['buffer_up_1'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_up_1'],
                'machine_time_bottleneck': MACHINE_TIME_UP_1,
                'buffer_bottleneck': res['buffer_up_1']
            },
            'down': {
                'transport_time': transport_time_agent_1_down_1,
                'buffer_out': res['buffer_down_1'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_down_1'],
                'machine_time_bottleneck': MACHINE_TIME_DOWN_1,
                'buffer_bottleneck': res['buffer_down_1']
            },
        },
        'container_in': None,
        'check_agent_in': res['check_agent_1_in'],
        'check_agent_out': res['check_agent_1_out'],
        'check_agent_blocking': res['check_agent_1_blocking'],
        'check_junction': res['check_junction_1'],
        'variables': ['ag_1', 'next_ope_1', 'up_1', 'down_1', 'up_2', 'down_2', 'buf_ag_1', 'buf_ag_2', 'th_1'],
        'target_positions': ['machine_agent_1', 'machine_up_1', 'machine_down_1',
                                'machine_up_2', 'machine_down_2', 'buffer_agent_1', 'buffer_agent_2']
    }

    config_up_1 = {
        'check_event': res['check_buf_up_1'],
        'buffer_in': res['buffer_up_1'],
        'buffer_out': res['buffer_up_2'],
        'machine': res['machine_up_1'],
        'machine_s': res['machine_up_1_s'],
        'machine_ops': machine_up_1_op,
        'machine_time': machine_time_up_1,
        'transport_time': transport_time_up_1_up_2,
        'name': 'UP1',
        'next_process_func': production_stage_before_junction,
        'next_config': None,
    }

    config_down_1 = {
        'check_event': res['check_buf_down_1'],
        'buffer_in': res['buffer_down_1'],
        'buffer_out': res['buffer_down_2'],
        'machine': res['machine_down_1'],
        'machine_s': res['machine_down_1_s'],
        'machine_ops': machine_down_1_op,
        'machine_time': machine_time_down_1,
        'transport_time': transport_time_down_1_down_2,
        'name': 'DOWN1',
        'next_process_func': production_stage_before_junction,
        'next_config': None,
    }

    config_up_2 = {
        'check_event': res['check_buf_up_2'],
        'buffer_in': res['buffer_up_2'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_up_2'],
        'machine_s': res['machine_up_2_s'],
        'machine_ops': machine_up_2_op,
        'machine_time': machine_time_up_2,
        'transport_time': transport_time_up_2_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': 'UP2',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': 'th_1',
        'config_agent': None,
    }

    config_down_2 = {
        'check_event': res['check_buf_down_2'],
        'buffer_in': res['buffer_down_2'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_down_2'],
        'machine_s': res['machine_down_2_s'],
        'machine_ops': machine_down_2_op,
        'machine_time': machine_time_down_2,
        'transport_time': transport_time_down_2_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': 'DOWN2',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': 'th_1',
        'config_agent': None
    }

    config_quality = {
        'check_event': res['check_buf_quality'],
        'buffer_in': res['buffer_quality'],
        'buffer_out': res['buffer_io'],
        'machine': res['machine_quality'],
        'machine_s': res['machine_quality_s'],
        'machine_ops': machine_quality_op,
        'machine_time': machine_time_quality,
        'transport_time': transport_time_quality_io,
        'container_in': res['container_quality'],
        'container_in_list': res['container_quality_list'],
        'name': 'QUALITY',
        'next_process_func': normal_io,
        'next_config': None,
    }

    config_io['next_config'] = config_agent_1

    config_agent_1['actions']['up']['next_config'] = config_up_1
    config_agent_1['actions']['down']['next_config'] = config_down_1

    config_up_1['next_config'] = config_up_2
    config_down_1['next_config'] = config_down_2

    config_up_2['next_config'] = config_quality
    config_up_2['config_agent'] = config_agent_1
    config_down_2['next_config'] = config_quality
    config_down_2['config_agent'] = config_agent_1

    config_quality['next_config'] = config_io

actions_agent1 = ['up', 'down']

agent1 = QLearningAgent(actions=actions_agent1, name='ag_1')

agents = [agent1]

# %% [markdown]
# ## Training

# %%
# Source Training

def source_train_RL(env, res, file):
    for i in range(AMOUNT_OF_PRODUCTS):
        t_source = SOURCE_TIME
        yield env.timeout(t_source)
        pallet_type = Pallets_List[i]
        pallet_type.pallet = i+1
        pallet_type.next_ope = 0
        yield res['buffer_agent_1'].put(pallet_type)
        que_agent = production_agent_RL(env, res, pallet_type, config_agent_1, file, train=True)
        env.process(que_agent)
    
    env.process(rl_dense(env, res, T_STEP, T_START, config_agent_1, 'th_1'))

def rl_dense(env, res, t_sampling, t_start, config_agent, th_code):
    if env.now < t_start:
        yield env.timeout(t_start - env.now)

    yield config_agent['check_agent_out']
    while True:
        action = 'wait'
        state = get_state(env, res, PALLET_STAR)
        reduced_state = reduce_state_train(state, config_agent['variables'], config_agent['target_positions'])
        clock = env.now
        yield AnyOf(env, [env.timeout(t_sampling), config_agent['check_junction']])
        clock = (env.now - clock)/t_sampling
        new_state = get_state(env, res, PALLET_STAR)
        new_reduced_state = reduce_state_train(new_state, config_agent['variables'], config_agent['target_positions'])
        reward = TH_P*new_reduced_state[th_code] - clock*STEP
        config_agent['agent'].update_agent(reduced_state, action, reward, new_reduced_state) 
        if new_reduced_state[th_code] == 1:
            yield config_agent['check_agent_out']

# %%
# Process and Run

seed_list_training = [1]
counts_training = []

for seed in seed_list_training:
    random.seed(seed)
    env, resources = create_environment()
    create_configs_RL(resources, agent1, 'train')
    log_filename = f"RLTraining_{seed}.txt"
    f = open(log_filename, "w")
    env.process(source_train_RL(env, resources, f))
    env.run(until=SIMULATION_LENGTH*50)
    f.close()
    counts_training.append(resources['pr_count'])
    print('Total Production of RL (Training): ', resources['pr_count'])
# Out:
# Total Production of RL (Training):  1895115

# %%
# Print Q-Table

for idx, ag in enumerate(agents):
    print('Agent', idx+1)
    print_q_table(ag)
    print('')
    print('')
# Out:
# Agent 1
# Q-table:
# State: (next_ope_1=1, queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0), Action: up -> Q-value: -977.4171
# State: (next_ope_1=1, queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0), Action: up -> Q-value: -977.9831
# State: (next_ope_1=0, queue=0, pos=machine_up_1, buf_ag_1=0, down_1=1, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -988.0089
# State: (next_ope_1=0, queue=0, pos=machine_up_1, buf_ag_1=1, down_1=1, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -987.9205
# State: (next_ope_1=0, queue=0, pos=machine_up_1, buf_ag_1=0, down_1=1, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -987.6269
# State: (next_ope_1=0, queue=0, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=2, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -987.8305
# State: (next_ope_1=0, queue=0, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -988.0897
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=0), Action: wait -> Q-value: -987.8302
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=2, slot=0), Action: wait -> Q-value: -987.4147
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -986.5945
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -987.5823
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=1, down_1=1, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -987.7088
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -987.4378
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -987.2254
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=3, slot=2), Action: wait -> Q-value: -987.0193
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=3, slot=3), Action: wait -> Q-value: -985.8649
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=0), Action: wait -> Q-value: -987.3459
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -986.3911
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -986.9005
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -986.0105
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -986.1546
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=2), Action: wait -> Q-value: -986.7592
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=2), Action: wait -> Q-value: -984.5940
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=3), Action: wait -> Q-value: -985.8248
# State: (next_ope_1=0, queue=0, pos=0, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=0, slot=0), Action: wait -> Q-value: -986.2515
# State: (next_ope_1=0, queue=0, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -987.7914
# State: (next_ope_1=1, queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=1, slot=0), Action: up -> Q-value: -977.7677
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=0), Action: wait -> Q-value: -987.7098
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=1), Action: wait -> Q-value: -987.5383
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -987.5034
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -986.9011
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -987.0609
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=1, slot=1), Action: wait -> Q-value: -986.3782
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=1, slot=1), Action: wait -> Q-value: -987.0724
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=1, slot=1), Action: wait -> Q-value: -986.8958
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=1, slot=1), Action: wait -> Q-value: -986.8386
# State: (next_ope_1=0, queue=0, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=0, slot=0), Action: wait -> Q-value: -987.6380
# State: (next_ope_1=1, queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0), Action: down -> Q-value: -978.1215
# State: (next_ope_1=0, queue=0, pos=machine_down_1, buf_ag_1=1, down_1=1, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=0, slot=0), Action: wait -> Q-value: -988.1697
# State: (next_ope_1=0, queue=1, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=2, th_1=0, up_2=0, slot=0), Action: wait -> Q-value: -988.4037
# State: (next_ope_1=0, queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=0, down_2=2, th_1=0, up_2=0, slot=0), Action: wait -> Q-value: -988.0763
# State: (next_ope_1=0, queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -988.3104
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -987
# State: (next_ope_1=0, queue=0, pos=machine_down_1, buf_ag_1=0, down_1=2, up_1=2, ag_1=0, down_2=0, th_1=0, up_2=0, slot=2), Action: wait -> Q-value: -5.5840
# State: (next_ope_1=1, queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=1, slot=0), Action: wait -> Q-value: -632.1146
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=3, slot=12), Action: wait -> Q-value: -356.8785
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=3, slot=13), Action: wait -> Q-value: -253.4200
# State: (next_ope_1=1, queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=3), Action: wait -> Q-value: -392.3183
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=2, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=2, slot=6), Action: wait -> Q-value: -389.7262
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=3, slot=13), Action: wait -> Q-value: -6.4000
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=3, slot=13), Action: wait -> Q-value: -8.7904
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=3, slot=14), Action: wait -> Q-value: -13.5426
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=3, slot=14), Action: wait -> Q-value: -404.1336
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=13), Action: wait -> Q-value: -410.8625
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=13), Action: wait -> Q-value: -18.4009
# State: (next_ope_1=1, queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=4), Action: wait -> Q-value: -393.7361
# State: (next_ope_1=1, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=1, slot=2), Action: wait -> Q-value: -630.5670
# State: (next_ope_1=1, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=3), Action: wait -> Q-value: -392.1407
# State: (next_ope_1=0, queue=0, pos=machine_up_1, buf_ag_1=1, down_1=1, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=1, slot=3), Action: wait -> Q-value: -394.7538
# State: (next_ope_1=0, queue=0, pos=machine_up_1, buf_ag_1=1, down_1=1, up_1=2, ag_1=0, down_2=0, th_1=0, up_2=0, slot=4), Action: wait -> Q-value: -5.5840
# State: (next_ope_1=1, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=3, slot=5), Action: wait -> Q-value: -393.9007
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=2, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=2, slot=3), Action: wait -> Q-value: -394.0280
# State: (next_ope_1=1, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=4), Action: wait -> Q-value: -385.6486
# State: (next_ope_1=1, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=4), Action: wait -> Q-value: -630.2214
# State: (next_ope_1=1, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=3), Action: wait -> Q-value: -394.1795
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=2, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=0, slot=8), Action: wait -> Q-value: -299.5661
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=2, ag_1=0, down_2=1, th_1=0, up_2=0, slot=12), Action: wait -> Q-value: -8.7904
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=2, ag_1=0, down_2=1, th_1=0, up_2=0, slot=13), Action: wait -> Q-value: -400.9537
# State: (next_ope_1=1, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=6), Action: wait -> Q-value: -393.0515
# State: (next_ope_1=1, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=2, slot=5), Action: wait -> Q-value: -619.7673
# State: (next_ope_1=1, queue=1, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=5), Action: wait -> Q-value: -392.7261
# State: (next_ope_1=0, queue=0, pos=machine_down_1, buf_ag_1=0, down_1=1, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=0, slot=2), Action: wait -> Q-value: -633.7786
# State: (next_ope_1=0, queue=0, pos=machine_down_1, buf_ag_1=0, down_1=1, up_1=2, ag_1=0, down_2=1, th_1=0, up_2=0, slot=2), Action: wait -> Q-value: -394.8007
# State: (next_ope_1=0, queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=1, slot=20), Action: wait -> Q-value: -106.0218
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=15), Action: wait -> Q-value: -25.2576
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=16), Action: wait -> Q-value: -25.2576
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=17), Action: wait -> Q-value: -25.2576
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=2, th_1=0, up_2=2, slot=18), Action: wait -> Q-value: -8.7904
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=18), Action: wait -> Q-value: -8.7904
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=2, slot=18), Action: wait -> Q-value: -394.0682
# State: (next_ope_1=0, queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=2, slot=7), Action: wait -> Q-value: -301.3857
# State: (next_ope_1=1, queue=2, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=3, slot=3), Action: wait -> Q-value: -394.3939
# State: (next_ope_1=0, queue=2, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=4, ag_1=0, down_2=0, th_1=0, up_2=0, slot=4), Action: wait -> Q-value: -25.2576
# State: (next_ope_1=0, queue=2, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=4, ag_1=0, down_2=0, th_1=0, up_2=0, slot=5), Action: wait -> Q-value: -398.9403
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=2, ag_1=0, down_2=1, th_1=0, up_2=0, slot=11), Action: wait -> Q-value: -111.1866
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=0, slot=14), Action: wait -> Q-value: -7.9840
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=0, slot=15), Action: wait -> Q-value: -7.4810
# State: (next_ope_1=0, queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=1, slot=15), Action: wait -> Q-value: -393.9897
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=2, slot=7), Action: wait -> Q-value: -226.3297
# State: (next_ope_1=0, queue=1, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=3, slot=12), Action: wait -> Q-value: -74.8653
# State: (next_ope_1=1, queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=4), Action: wait -> Q-value: -377.9651

# %%
# Print Sorted Q-Table

for idx, ag in enumerate(agents):
    print('Agent', idx+1)
    print_sorted_q_table(ag)
    print('')
    print('')
# Out:
# Agent 1
# Sorted Q-table:
#
# State: (next_ope_1='0', queue=0, pos=0, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -986.2515
#
# State: (next_ope_1='0', queue=0, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -987.5216
#
# State: (next_ope_1='0', queue=0, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -987.8130
#
# State: (next_ope_1='0', queue=0, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=2, slot=0)
#   Action: wait -> Q-value: -988.5207
#
# State: (next_ope_1='0', queue=0, pos=machine_up_1, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=0, th_1=0, up_2=3, slot=0)
#   Action: wait -> Q-value:
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=12)
#   Action: wait -> Q-value: -389.4331
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=2)
#   Action: wait -> Q-value: -985.6877
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=3)
#   Action: wait -> Q-value: -981.8869
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=4)
#   Action: wait -> Q-value: -917.1607
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=5)
#   Action: wait -> Q-value: -810.0234
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=6)
#   Action: wait -> Q-value: -865.7132
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=7)
#   Action: wait -> Q-value: -629.2229
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=8)
#   Action: wait -> Q-value: -298.4996
#
# State: (next_ope_1='0', queue=3, pos=machine_up_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=0, th_1=0, up_2=4, slot=9)
#   Action: wait -> Q-value: -650.6628
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -987.0796
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -986.9007
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=0)
#   Action: wait -> Q-value: -986.6331
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=3, slot=0)
#   Action: wait -> Q-value: -986.3325
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -986.7742
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -986.7944
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=2, slot=0)
#   Action: wait -> Q-value: -986.3648
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=2, ag_1=0, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -986.9618
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=2, ag_1=0, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -985.3397
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=3, ag_1=0, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -986.4186
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -986.9901
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -986.6854
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=2, slot=1)
#   Action: wait -> Q-value: -985.6813
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=0, ag_1=0, down_2=1, th_1=0, up_2=3, slot=1)
#   Action: wait -> Q-value: -984.0844
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -986.0534
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -986.6903
#
# State: (next_ope_1='0', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=0, up_1=1, ag_1=0, down_2=1, th_1=0, up_2=2, slot=1)
# ...
#   Action: wait -> Q-value: -899.6143
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=0, down_1=1, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -907.4491
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -394.2579
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -760.9446
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -854.3274
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -389.8456
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -628.1384
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -904.5718
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -851.8185
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=2)
#   Action: wait -> Q-value: -600.6546
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=3)
#   Action: wait -> Q-value: -394.1795
#
# State: (next_ope_1='1', queue=0, pos=machine_up_1, buf_ag_1=0, down_1=1, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -629.6420
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -934.4738
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -969.3072
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -976.3209
#   Action: up -> Q-value: -975.9912
#   Action: wait -> Q-value: -724.4409
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -559.7016
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -600.4754
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=0, down_1=1, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=4)
#   Action: wait -> Q-value: -297.4042
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=2, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -976.7371
#   Action: up -> Q-value: -976.5962
#   Action: wait -> Q-value: -393.4091
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=2, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: down -> Q-value: -978.0958
#   Action: up -> Q-value: -977.0930
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=2, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -977.2698
#   Action: up -> Q-value: -976.9311
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=0, down_1=2, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -385.0071
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=0, down_1=2, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -369.4136
#
# State: (next_ope_1='1', queue=1, pos=machine_down_1, buf_ag_1=0, down_1=2, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -590.7797
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=0, down_1=2, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -618.0889
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=2, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -974.7786
#   Action: up -> Q-value: -974.2876
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=0, down_1=2, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -505.3821
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=0, down_1=3, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -965.9633
#   Action: up -> Q-value: -963.7186
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -939.9597
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -902.5038
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=0)
#   Action: wait -> Q-value: -394.6056
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -722.4728
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -622.6786
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -971.3377
#   Action: up -> Q-value: -977.3673
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: down -> Q-value: -977.4721
#   Action: up -> Q-value: -977.6237
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=0)
#   Action: down -> Q-value: -976.4128
#   Action: up -> Q-value: -978.3108
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -977.2543
#   Action: up -> Q-value: -977.6770
#   Action: wait -> Q-value: -609.2668
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: down -> Q-value: -976.7376
#   Action: up -> Q-value: -977.8222
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=2, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -977.4352
#   Action: up -> Q-value: -977.4804
#
# State: (next_ope_1='1', queue=0, pos=machine_up_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -627.1059
#
# State: (next_ope_1='1', queue=0, pos=machine_up_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -393.6150
#
# State: (next_ope_1='1', queue=0, pos=machine_up_1, buf_ag_1=1, down_1=0, up_1=2, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -393.3687
#
# State: (next_ope_1='1', queue=0, pos=machine_up_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -392.4897
#
# State: (next_ope_1='1', queue=1, pos=machine_up_1, buf_ag_1=1, down_1=0, up_1=2, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -387.4993
#
# State: (next_ope_1='1', queue=1, pos=machine_up_1, buf_ag_1=1, down_1=0, up_1=2, ag_1=1, down_2=0, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -377.8477
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -857.0046
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=0)
#   Action: wait -> Q-value: -393.6716
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -667.9665
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -771.0472
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=1)
#   Action: wait -> Q-value: -772.2339
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=3)
#   Action: wait -> Q-value: -392.3183
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=4)
#   Action: wait -> Q-value: -325.5153
#
# State: (next_ope_1='1', queue=1, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=1)
#   Action: wait -> Q-value: -768.4087
#
# State: (next_ope_1='1', queue=1, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=2, slot=3)
#   Action: wait -> Q-value: -384.9300
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -979.2282
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -976.0132
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -905.5479
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -978.0232
#   Action: up -> Q-value: -977.5039
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: down -> Q-value: -978.3771
#   Action: up -> Q-value: -977.8815
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -978.1088
#   Action: up -> Q-value: -978.0845
#   Action: wait -> Q-value: -855.4196
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -391.1967
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -393.6402
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -965.6120
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -768.6996
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -754.5267
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=2)
#   Action: wait -> Q-value: -392.3689
#
# State: (next_ope_1='1', queue=0, pos=machine_up_1, buf_ag_1=1, down_1=0, up_1=1, ag_1=1, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -617.6830
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -392.6691
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=1, slot=1)
#   Action: wait -> Q-value: -948.1972
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -731.5052
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -978.7691
#   Action: up -> Q-value: -977.4890
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -321.6652
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -591.6656
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=2)
#   Action: wait -> Q-value: -630.2943
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=4)
#   Action: wait -> Q-value: -542.3766
#
# State: (next_ope_1='1', queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -623.2726
#
# State: (next_ope_1='1', queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=4)
#   Action: wait -> Q-value: -393.7361
#
# State: (next_ope_1='1', queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=7)
#   Action: wait -> Q-value: -374.4943
#
# State: (next_ope_1='1', queue=1, pos=machine_down_2, buf_ag_1=1, down_1=0, up_1=0, ag_1=1, down_2=2, th_1=0, up_2=0, slot=8)
#   Action: wait -> Q-value: -382.2973
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -839.6974
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -940.3462
#
# State: (next_ope_1='1', queue=1, pos=buffer_agent_1, buf_ag_1=1, down_1=1, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -394.1027
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -977.3437
#   Action: up -> Q-value: -976.4438
#   Action: wait -> Q-value: -391.8333
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: down -> Q-value: -978.3995
#   Action: up -> Q-value: -977.8352
#   Action: wait -> Q-value: -768.6403
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=1, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -977.9421
#   Action: up -> Q-value: -977.3873
#   Action: wait -> Q-value: -393.8997
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -631.3272
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=1, down_1=1, up_1=1, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: wait -> Q-value: -236.6486
#
# State: (next_ope_1='1', queue=0, pos=machine_up_2, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=1, slot=0)
#   Action: wait -> Q-value: -772.5641
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -976.0374
#   Action: up -> Q-value: -975.5639
#   Action: wait -> Q-value: -620.9411
#
# State: (next_ope_1='1', queue=0, pos=machine_down_2, buf_ag_1=1, down_1=1, up_1=0, ag_1=1, down_2=1, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -618.7266
#
# State: (next_ope_1='1', queue=0, pos=machine_agent_1, buf_ag_1=1, down_1=2, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=0)
#   Action: down -> Q-value: -974.3187
#   Action: up -> Q-value: -974.8455
#
# State: (next_ope_1='1', queue=0, pos=machine_down_1, buf_ag_1=1, down_1=2, up_1=0, ag_1=1, down_2=0, th_1=0, up_2=0, slot=1)
#   Action: wait -> Q-value: -354.7371

# %% [markdown]
# ## Test

# %%
# Process and Run

counts_test = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs_RL(resources, agent1, 'test')
    log_filename = f"RLTest_{seed}.txt"
    f = open(log_filename, "w")
    env.process(source(env, resources, production_agent_RL, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_test.append(resources['pr_count'])
    print('Total Production of RL (Test): ', resources['pr_count'])
# Out:
# Total Production of RL (Test):  39196
# Total Production of RL (Test):  39064
# Total Production of RL (Test):  38808
# Total Production of RL (Test):  39163
# Total Production of RL (Test):  39055
