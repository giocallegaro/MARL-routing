# %% [markdown]
# # Import and Constants

# %%
# Import

import simpy
from simpy.events import AnyOf
import numpy as np
from numpy import random
import pandas as pd

import statistics
import matplotlib.pyplot as plt

from scipy.stats import t

# %%
# Constants

AMOUNT_OF_PRODUCTS = 14

a = 0.05

MACHINE_TIME_IO = 1.05

MACHINE_TIME_AGENT_1 = 0.001
MACHINE_TIME_1A = 2.05
MACHINE_TIME_1B = 5.05

MACHINE_TIME_AGENT_2 = 0.001
MACHINE_TIME_AGENT_3 = 0.001
MACHINE_TIME_2A = 4.05
MACHINE_TIME_2B = 7.05
MACHINE_TIME_2C = 4.05
MACHINE_TIME_2D = 5.05

MACHINE_TIME_AGENT_4 = 0.001
MACHINE_TIME_3A = 1.05
MACHINE_TIME_3B = 3.05
MACHINE_TIME_3C = 4.05
MACHINE_TIME_3D = 6.05

MACHINE_TIME_QUALITY = 1.05

machine_time_io = lambda: random.uniform(MACHINE_TIME_IO-a,MACHINE_TIME_IO+a)

machine_time_1a = lambda: random.exponential(MACHINE_TIME_1A)
machine_time_1b = lambda: random.uniform(MACHINE_TIME_1B-a,MACHINE_TIME_1B+a)

machine_time_2a = lambda: random.uniform(MACHINE_TIME_2A-a,MACHINE_TIME_2A+a)
machine_time_2b = lambda: random.exponential(MACHINE_TIME_2B)
machine_time_2c = lambda: random.exponential(MACHINE_TIME_2C)
machine_time_2d = lambda: random.uniform(MACHINE_TIME_2D-a,MACHINE_TIME_2D+a)

machine_time_3a = lambda: random.uniform(MACHINE_TIME_3A-a,MACHINE_TIME_3A+a)
machine_time_3b = lambda: random.uniform(MACHINE_TIME_3B-a,MACHINE_TIME_3B+a)
machine_time_3c = lambda: random.uniform(MACHINE_TIME_3C-a,MACHINE_TIME_3C+a)
machine_time_3d = lambda: random.exponential(MACHINE_TIME_3D)

machine_time_quality = lambda: random.uniform(MACHINE_TIME_QUALITY-a,MACHINE_TIME_QUALITY+a)

TRANSPORT_TIME_IO_AGENT_1 = 1.05

TRANSPORT_TIME_AGENT1_1A = 1.05
TRANSPORT_TIME_AGENT1_1B = 1.05

TRANSPORT_TIME_1A_AGENT2 = 1.05
TRANSPORT_TIME_1B_AGENT3 = 1.05

TRANSPORT_TIME_AGENT2_2A = 1.05
TRANSPORT_TIME_AGENT2_2B = 1.05

TRANSPORT_TIME_AGENT3_2C = 1.05
TRANSPORT_TIME_AGENT3_2D = 1.05

TRANSPORT_TIME_2A_3A = 1.05
TRANSPORT_TIME_2B_3A = 1.05

TRANSPORT_TIME_2C_3B = 1.05

TRANSPORT_TIME_2D_AGENT4 = 1.05/2

TRANSPORT_TIME_AGENT4_3C = 1.05/2
TRANSPORT_TIME_AGENT4_3D = 1.05/2

TRANSPORT_TIME_3A_QUALITY = 1.05
TRANSPORT_TIME_3B_QUALITY = 1.05
TRANSPORT_TIME_3C_QUALITY = 1.05
TRANSPORT_TIME_3D_QUALITY = 1.05

TRANSPORT_TIME_QUALITY_IO = 1.05

transport_time_io_agent_1 = lambda: random.uniform(TRANSPORT_TIME_IO_AGENT_1-a,TRANSPORT_TIME_IO_AGENT_1+a)

transport_time_agent1_1a = lambda: random.uniform(TRANSPORT_TIME_AGENT1_1A-a,TRANSPORT_TIME_AGENT1_1A+a)
transport_time_agent1_1b = lambda: random.uniform(TRANSPORT_TIME_AGENT1_1B-a,TRANSPORT_TIME_AGENT1_1B+a)

transport_time_1a_agent2 = lambda: random.uniform(TRANSPORT_TIME_1A_AGENT2-a,TRANSPORT_TIME_1A_AGENT2+a)
transport_time_1b_agent3 = lambda: random.uniform(TRANSPORT_TIME_1B_AGENT3-a,TRANSPORT_TIME_1B_AGENT3+a)

transport_time_agent2_2a = lambda: random.uniform(TRANSPORT_TIME_AGENT2_2A-a,TRANSPORT_TIME_AGENT2_2A+a)
transport_time_agent2_2b = lambda: random.uniform(TRANSPORT_TIME_AGENT2_2B-a,TRANSPORT_TIME_AGENT2_2B+a)

transport_time_agent3_2c = lambda: random.uniform(TRANSPORT_TIME_AGENT3_2C-a,TRANSPORT_TIME_AGENT3_2C+a)
transport_time_agent3_2d = lambda: random.uniform(TRANSPORT_TIME_AGENT3_2D-a,TRANSPORT_TIME_AGENT3_2D+a)

transport_time_2a_3a = lambda: random.uniform(TRANSPORT_TIME_2A_3A-a,TRANSPORT_TIME_2A_3A+a)
transport_time_2b_3a = lambda: random.uniform(TRANSPORT_TIME_2B_3A-a,TRANSPORT_TIME_2B_3A+a)

transport_time_2c_3b = lambda: random.uniform(TRANSPORT_TIME_2C_3B-a,TRANSPORT_TIME_2C_3B+a)

transport_time_2d_agent4 = lambda: random.uniform(TRANSPORT_TIME_2D_AGENT4-a,TRANSPORT_TIME_2D_AGENT4+a)

transport_time_agent4_3c = lambda: random.uniform(TRANSPORT_TIME_AGENT4_3C-a,TRANSPORT_TIME_AGENT4_3C+a)
transport_time_agent4_3d = lambda: random.uniform(TRANSPORT_TIME_AGENT4_3D-a,TRANSPORT_TIME_AGENT4_3D+a)

transport_time_3a_quality = lambda: random.uniform(TRANSPORT_TIME_3A_QUALITY-a,TRANSPORT_TIME_3A_QUALITY+a)
transport_time_3b_quality = lambda: random.uniform(TRANSPORT_TIME_3B_QUALITY-a,TRANSPORT_TIME_3B_QUALITY+a)
transport_time_3c_quality = lambda: random.uniform(TRANSPORT_TIME_3C_QUALITY-a,TRANSPORT_TIME_3C_QUALITY+a)
transport_time_3d_quality = lambda: random.uniform(TRANSPORT_TIME_3D_QUALITY-a,TRANSPORT_TIME_3D_QUALITY+a)

transport_time_quality_io = lambda: random.uniform(TRANSPORT_TIME_QUALITY_IO-a,TRANSPORT_TIME_QUALITY_IO+a)

SOURCE_TIME = 1

SEED_PALLET = 42

CAP_BUF_IO = 3
CAP_BUF_AGENT_1 = 3
CAP_BUF_1A = 3
CAP_BUF_1B = 3
CAP_BUF_AGENT_2 = 3
CAP_BUF_AGENT_3 = 3
CAP_BUF_2A = 3
CAP_BUF_2B = 3
CAP_BUF_2C = 3
CAP_BUF_2D = 3
CAP_BUF_3A = 3
CAP_BUF_3B = 3
CAP_BUF_AGENT_4 = 3
CAP_BUF_3C = 3
CAP_BUF_3D = 3
CAP_BUF_QUALITY = 3

SIMULATION_LENGTH = 500000
NUM_PALLET = 9000000

T_STEP = 0.999764/2
T_START = AMOUNT_OF_PRODUCTS + 0.5
IO_LAG = 0.0001
JUNCTION_LAG = 0.0001

M = 1000
OCC = 10
TH_P = 1000
STEP = 10

PALLET_STAR = 1
seed_list = [1, 2, 3, 4, 5]

# %% [markdown]
# # Simulation Functions

# %%
# Pallets

sequences = ['12345']

class Pallet:
    def __init__(self, sequence, next_ope, pallet, product):
        self.sequence = sequence
        self.next_ope = next_ope
        self.pallet = pallet
        self.product = product
        
    def __repr__(self):
        return (f'Pallet {self.pallet} carrying Product {self.product} with sequence {self.sequence}, next operation: {self.sequence[self.next_ope]}')

random.seed(SEED_PALLET)

Pallets_List = []
for i in range(NUM_PALLET):
    p = Pallet('12345', 0, 0, i+1) #sequences[random.randint(0,len(sequences)-1)]
    Pallets_List.append(p)

# %%
# Environments

def create_environment():

    env = simpy.Environment()

    resources = {
        'env': env,

        'machine_io': simpy.Resource(env,capacity=1),
        'machine_agent_1': simpy.Resource(env,capacity=1),
        'machine_1a': simpy.Resource(env,capacity=1),
        'machine_1b': simpy.Resource(env,capacity=1),
        'machine_agent_2': simpy.Resource(env,capacity=1),
        'machine_agent_3': simpy.Resource(env,capacity=1),
        'machine_2a': simpy.Resource(env,capacity=1),
        'machine_2b': simpy.Resource(env,capacity=1),
        'machine_2c': simpy.Resource(env,capacity=1),
        'machine_2d': simpy.Resource(env,capacity=1),
        'machine_agent_4': simpy.Resource(env,capacity=1),
        'machine_3a': simpy.Resource(env,capacity=1),
        'machine_3b': simpy.Resource(env,capacity=1),
        'machine_3c': simpy.Resource(env,capacity=1),
        'machine_3d': simpy.Resource(env,capacity=1),
        'machine_quality': simpy.Resource(env,capacity=1),

        'machine_io_s': simpy.Resource(env,capacity=1),
        'machine_1a_s': simpy.Resource(env,capacity=1),
        'machine_1b_s': simpy.Resource(env,capacity=1),
        'machine_2a_s': simpy.Resource(env,capacity=1),
        'machine_2b_s': simpy.Resource(env,capacity=1),
        'machine_2c_s': simpy.Resource(env,capacity=1),
        'machine_2d_s': simpy.Resource(env,capacity=1),
        'machine_3a_s': simpy.Resource(env,capacity=1),
        'machine_3b_s': simpy.Resource(env,capacity=1),
        'machine_3c_s': simpy.Resource(env,capacity=1),
        'machine_3d_s': simpy.Resource(env,capacity=1),
        'machine_quality_s': simpy.Resource(env,capacity=1),

        'buffer_io': simpy.FilterStore(env, capacity=CAP_BUF_IO),
        'buffer_agent_1': simpy.FilterStore(env, capacity=CAP_BUF_AGENT_1),
        'buffer_1a': simpy.FilterStore(env, capacity=CAP_BUF_1A),
        'buffer_1b': simpy.FilterStore(env, capacity=CAP_BUF_1B),
        'buffer_agent_2': simpy.FilterStore(env, capacity=CAP_BUF_AGENT_2),
        'buffer_agent_3': simpy.FilterStore(env, capacity=CAP_BUF_AGENT_3),
        'buffer_2a': simpy.FilterStore(env, capacity=CAP_BUF_2A),
        'buffer_2b': simpy.FilterStore(env, capacity=CAP_BUF_2B),
        'buffer_2c': simpy.FilterStore(env, capacity=CAP_BUF_2C),
        'buffer_2d': simpy.FilterStore(env, capacity=CAP_BUF_2D),
        'buffer_agent_4': simpy.FilterStore(env, capacity=CAP_BUF_AGENT_4),
        'buffer_3a': simpy.FilterStore(env, capacity=CAP_BUF_3A),
        'buffer_3b': simpy.FilterStore(env, capacity=CAP_BUF_3B),
        'buffer_3c': simpy.FilterStore(env, capacity=CAP_BUF_3C),
        'buffer_3d': simpy.FilterStore(env, capacity=CAP_BUF_3D),
        'buffer_quality': simpy.FilterStore(env, capacity=CAP_BUF_QUALITY),

        'check_buf_io': env.event(),

        'check_agent_1_in': env.event(),
        'check_agent_1_out': env.event(),
        'check_agent_1_blocking': env.event(),
        'check_junction_1': env.event(),

        'check_buf_1a': env.event(),
        'check_buf_1b': env.event(),

        'check_agent_2_in': env.event(),
        'check_agent_2_out': env.event(),
        'check_agent_2_blocking': env.event(),
        'check_junction_2': env.event(),

        'check_agent_3_in': env.event(),
        'check_agent_3_out': env.event(),
        'check_agent_3_blocking': env.event(),
        'check_junction_3': env.event(),

        'check_buf_2a': env.event(),
        'check_buf_2b': env.event(),
        'check_buf_2c': env.event(),
        'check_buf_2d': env.event(),

        'check_buf_3a': env.event(),
        'check_buf_3b': env.event(),

        'check_agent_4_in': env.event(),
        'check_agent_4_out': env.event(),
        'check_agent_4_blocking': env.event(),
        'check_junction_4': env.event(),

        'check_buf_3c': env.event(),
        'check_buf_3d': env.event(),

        'check_buf_quality': env.event(),

        'check_production_event': env.event(),

        'container_3a': simpy.Container(env, capacity=CAP_BUF_3A+1, init=CAP_BUF_3A+1),
        'container_quality': simpy.Container(env, capacity=CAP_BUF_QUALITY+1, init=CAP_BUF_QUALITY+1),

        'containers_list': ['3a', 'quality'],
        'container_3a_list': [],
        'container_quality_list': [],

        'q_enter': 0,
        't_enter': 0,
        't_enter_agent1': 0,
        't_enter_agent2': 0,
        't_enter_agent3': 0,
        't_enter_agent4': 0,
        'flow': 0,
        'flow_time': [],
        'j': AMOUNT_OF_PRODUCTS,
        'th': 0, 
        'th_1': 0,
        'th_2': 0,
        'th_3': 0,
        'th_4': 0,
        'pr_count': 0
        }

    return env, resources

machines_list = ['io', '1a', '1b', '2a', '2b', '2c', '2d', '3a', '3b', '3c', '3d', 'quality']
agents_list = ['agent_1', 'agent_2', 'agent_3', 'agent_4']

machine_1a_op = ['1']
machine_1b_op = ['1']

machine_2a_op = ['2']
machine_2b_op = ['2']
machine_2c_op = ['2']
machine_2d_op = ['2']

machine_3a_op = ['3']
machine_3b_op = ['3']
machine_3c_op = ['3']
machine_3d_op = ['3']

machine_quality_op = ['4']

machine_io_op = ['5']

all_op = set()
for machine in machines_list:
    ops = globals()[f'machine_{machine}_op']
    all_op.update(ops)
all_op = list(all_op)

# %%
# Production Functions (without Prints)

def normal_production_stage(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users)!= res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def normal_io(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f'{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n')

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_stage_before_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
            
            config['check_event'].succeed(); config['check_event'] = env.event()
            
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield container_out.get(1)    
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users)!= res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)

    container_out_list.append(pallet)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)

    if pallet.pallet == PALLET_STAR:
        for th_key, th_cfg in config['th'].items():
            res[th_key] = 1
            th_cfg['config_agent']['check_junction'].succeed(); th_cfg['config_agent']['check_junction'] = env.event()    
        
        yield env.timeout(JUNCTION_LAG)

        for th_key in config['th']:
            res[th_key] = 0

    del container_out_list[0]
    yield buffer_out.put(pallet)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def normal_stage_before_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
            
            config['check_event'].succeed(); config['check_event'] = env.event()
            
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield container_out.get(1)    
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users)!= res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)

    container_out_list.append(pallet)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)

    del container_out_list[0]
    yield buffer_out.put(pallet)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def io_before_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f'{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n')

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield container_out.get(1)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)

    container_out_list.append(pallet)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    del container_out_list[0]
    yield buffer_out.put(pallet)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_stage_after_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    yield container_in.put(1)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def io_after_junction(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f'{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n')

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield buffer_out.put(pallet)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield buffer_out.put(pallet)

    yield container_in.put(1)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_stage_between_junctions(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()

            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield container_out.get(1)    
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)
    
    container_out_list.append(pallet)
    yield container_in.put(1)

    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)

    if pallet.pallet == PALLET_STAR:
        for th_key, th_cfg in config['th'].items():
            res[th_key] = 1
            th_cfg['config_agent']['check_junction'].succeed(); th_cfg['config_agent']['check_junction'] = env.event()
        
        yield env.timeout(JUNCTION_LAG)

        for th_key in config['th']:
            res[th_key] = 0

    del container_out_list[0]
    yield buffer_out.put(pallet)

    env.process(next_process_func(env, res, pallet, next_config, f, train))

def normal_stage_between_junctions(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()

            yield env.timeout(machine_time)
            pallet.next_ope += 1
            yield container_out.get(1)    
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now

            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)
    
    container_out_list.append(pallet)
    yield container_in.put(1)

    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)

    del container_out_list[0]
    yield buffer_out.put(pallet)

    env.process(next_process_func(env, res, pallet, next_config, f, train))

def io_between_junctions(env, res, pallet, config, f, train=False):
    check_event = config['check_event']
    buffer_in = config['buffer_in']
    buffer_out = config['buffer_out']
    machine = config['machine']
    machine_s = config['machine_s']
    machine_ops = config['machine_ops']
    machine_time = config['machine_time']()
    transport_time = config['transport_time']()
    container_in = config['container_in']
    container_in_list = config['container_in_list']
    container_out = config['container_out']
    container_out_list = config['container_out_list']
    io_lag = config['io_lag']
    next_process_func = config['next_process_func']
    next_config = config['next_config']

    while True:
        if buffer_in.items[0] is pallet:
            break
        yield config['check_event']

    if pallet.sequence[pallet.next_ope] in machine_ops:
        with machine.request() as req:
            req.pallet = pallet
            yield req
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now
                res['flow'] = env.now - res['flow']
                res['flow_time'].append(res['flow'])

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield env.timeout(machine_time)

            if pallet.pallet == PALLET_STAR:
                res['th'] = 1
                config['check_production_event'].succeed(); config['check_production_event'] = env.event()
                yield env.timeout(io_lag)
                res['th'] = 0

            if not train:
                f.write(f'{pallet.pallet} {pallet.product} {env.now} EXIT_IO\n')

            res['pr_count'] += 1
            old_pallet = pallet
            pallet = Pallets_List[res['j']]
            pallet.pallet = old_pallet.pallet
            pallet.next_ope = 0
            res['j'] += 1
            yield container_out.get(1)
    else:
        with machine_s.request() as req_s:
            req_s.pallet = pallet
            yield req_s
            yield buffer_in.get(lambda obj: obj is pallet)

            for idx, items in enumerate(buffer_in.items):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) != res['q_enter']:
                        res['t_enter'] = env.now
            for idx, items in enumerate(container_in_list):
                if items.pallet == PALLET_STAR:
                    if idx + len(machine.users) + len(buffer_in.items) != res['q_enter']:
                        res['t_enter'] = env.now

            if pallet.pallet == PALLET_STAR:
                res['t_enter'] = env.now

            config['check_event'].succeed(); config['check_event'] = env.event()
            yield container_out.get(1)

    container_out_list.append(pallet)
    yield container_in.put(1)
    if pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

    yield env.timeout(transport_time)
    del container_out_list[0]
    yield buffer_out.put(pallet)
    
    env.process(next_process_func(env, res, pallet, next_config, f, train))

def production_agent_RL(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    agent = config['agent']
    mode = config['mode']
    actions = config['actions']
    container_in = config['container_in']
    event_in = config['check_agent_in']
    event_out = config['check_agent_out']
    event_blocking = config['check_agent_blocking']
    variables = config['variables']
    aux_variables = config['aux_variables']
    light_on = config['light_on']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)

        if pallet.pallet == PALLET_STAR:
            res['t_enter'] = env.now
            res[config['t_enter_agent']] = env.now

        if not train:
            f.write(f'{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n')

        state = get_state(env, res, PALLET_STAR)

        if mode == 'train' and pallet.pallet == PALLET_STAR:
            reduced_state = reduce_state_train(state, variables, light_on)
            #print('stato agente',reduced_state)
        else:
            reduced_state = reduce_state_test(state, variables, light_on)
            
        
        
        yield env.timeout(machine_time_agent)

        if mode == 'train' and pallet.pallet == PALLET_STAR:
            agent_decision = agent.choose_action_train(reduced_state)
        if mode == 'train' and pallet.pallet != PALLET_STAR:
            agent_decision = agent.choose_action_test(reduced_state) 
        if mode == 'test':
            agent_decision = agent.choose_action_test(reduced_state, p=True)

        action_config = actions[agent_decision]
        reward = 0
        blocking = 0

        if mode == 'train' and pallet.pallet == PALLET_STAR:
            if 'requires_container_out' in action_config:
                if action_config['container_out'].level == 0:
                    blocking = 1
                    new_state = get_state(env, res, PALLET_STAR)
                    new_reduced_state = reduce_state_train(new_state, variables, light_on)
                    if agent == agent1:
                        agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state,pr=False)
                    else:
                        agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state)
                    config['check_agent_out'].succeed(); config['check_agent_out'] = env.event()
            else:
                if len(action_config['buffer_out'].items) == action_config['buffer_out'].capacity:
                    blocking = 1                        
                    new_state = get_state(env, res, PALLET_STAR)
                    new_reduced_state = reduce_state_train(new_state, variables, light_on)
                    if agent == agent1:
                        agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state,pr=False)
                    else:
                        agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state)
                    config['check_agent_out'].succeed(); config['check_agent_out'] = env.event()

        
        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)        
    
    if mode == 'train' and pallet.pallet == PALLET_STAR:
        res['t_enter'] = env.now
        res['flow'] = env.now
        res['q_enter'] = get_state(env, res, PALLET_STAR)['queue']

        if blocking == 0:
            new_state = get_state(env, res, PALLET_STAR)
            new_reduced_state = reduce_state_train(new_state, variables, light_on)
            
            if agent == agent1:
                agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state,pr=False)
            else:
                agent.update_agent(reduced_state, agent_decision, reward, new_reduced_state)
            config['check_agent_out'].succeed(); config['check_agent_out'] = env.event()

    if container_in:
        yield container_in.put(1)
    
    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)

    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

def production_agent_random(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    actions = config['actions'] 
    container_in = config['container_in']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)

        f.write(f'{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n')
        yield env.timeout(machine_time_agent)
        agent_decision = random.choice(list(config['actions'].keys()))
        action_config = actions[agent_decision]

        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['flow'] = env.now

    if container_in:
        yield container_in.put(1)

    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)
        
    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

def production_agent_heuristic_th(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    actions = config['actions'] 
    container_in = config['container_in']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)
        f.write(f'{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n')
        yield env.timeout(machine_time_agent)

        buffer_counts = {
            action: len(actions[action]['buffer_out'].items)
            for action in actions
        }

        min_count = min(buffer_counts.values())

        candidates = [action for action, count in buffer_counts.items() if count == min_count]

        for preferred_action in config['priority']:
            if preferred_action in candidates:
                agent_decision = preferred_action
                break

        action_config = actions[agent_decision]

        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['flow'] = env.now

    if container_in:
        yield container_in.put(1)

    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)

    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

def production_agent_heuristic_flow(env, res, pallet, config, f, train=False):
    machine_agent = config['machine_agent']
    buffer_agent = config['buffer_agent']
    machine_time_agent = config['machine_time_agent']
    actions = config['actions'] 
    container_in = config['container_in']

    with machine_agent.request() as req_agent:
        req_agent.pallet = pallet
        yield req_agent
        yield buffer_agent.get(lambda p: p == pallet)
        f.write(f'{pallet.pallet} {pallet.product} {env.now} ENTERS_AGENT\n')
        yield env.timeout(machine_time_agent)

        best_action = None
        min_value = float('inf')

        for direction, values in actions.items():
            buffer_len = len(values['buffer_bottleneck'].items)
            machine_users = len(values['machine_bottleneck'].users)
            machine_time = values['machine_time_bottleneck']
    
            value = (1 + buffer_len + machine_users) * machine_time
    
            if value < min_value:
                min_value = value
                best_action = direction

        agent_decision = best_action

        action_config = actions[agent_decision]

        if 'requires_container_out' in action_config:
            yield action_config['container_out'].get(1)
            action_config['container_out_list'].append(pallet)
        else:
            yield action_config['buffer_out'].put(pallet)

    if pallet.pallet == PALLET_STAR:
        res['flow'] = env.now

    if container_in:
        yield container_in.put(1)

    yield env.timeout(action_config['transport_time']())
    if 'requires_container_out' in action_config:
        del action_config['container_out_list'][0]
        yield action_config['buffer_out'].put(pallet)

    env.process(action_config['next_process_func'](env, res, pallet, action_config['next_config'], f, train))

# %%
# Get State Function

def get_state(env, res, pallet):

    state = {}
    pos = '0'
    queue = 0
    slot = 0
    time = env.now - res['t_enter']
    th_pr = res['th']

    counters = {}

    for agent_name in agents_list:
        idx = agent_name.split('_')[1]

        ag_key = f'agent_{idx}'
        next_ope_key = f'next_ope_{idx}'
        buf_key = f'buf_ag_{idx}'
        th_key = f'th_{idx}'
        t_enter_key = f't_enter_agent{idx}'

        ag_val = 0
        next_ope_val = '0'
        buf_val = 0

        machine_obj = res[f'machine_{agent_name}']
        buffer_obj = res[f'buffer_{agent_name}']

        if machine_obj.users:
            ag_val = 1
            next_ope_val = machine_obj.users[0].pallet.sequence[machine_obj.users[0].pallet.next_ope]
            if machine_obj.users[0].pallet.pallet == pallet:
                pos = f'machine_{agent_name}'
                queue = 0

        if buffer_obj.items:
            for idx_buf, item in enumerate(buffer_obj.items):
                buf_val += 1
                if item.pallet == pallet:
                    pos = f'buf_ag_{idx}'
                    queue = idx_buf+1 if machine_obj.users else idx_buf

        if agent_name in res['containers_list']:
            for idx_cont, item in enumerate(f'container_{agent_name}_list'.items):
                buf_val += 1
                if item.pallet == pallet:
                    pos = f'buf_ag_{idx}'
                    queue = idx_cont + len(buffer_obj.items) + (1 if machine_obj.users else 0)

        state[ag_key] = ag_val
        state[next_ope_key] = next_ope_val
        state[buf_key] = buf_val
        state[th_key] = res[th_key]
        state[t_enter_key] = res[t_enter_key]

    all_op = set()
    for machine in machines_list:
        name = str(machine)
        op_list = globals()[f'machine_{name}_op']
        all_op.update(op_list)
    all_op = list(all_op)

    for machine in machines_list:
        name = str(machine)
        op_list = globals()[f'machine_{name}_op']
        not_handled_ops = set(all_op) - set(op_list)

        counters[name] = 0
        for op in not_handled_ops:
            counters[f'{name}_s{op}'] = 0

        buffer = res[f'buffer_{name}']
        machine_obj = res[f'machine_{name}']

        for idx, item in enumerate(buffer.items):
            next_op = item.sequence[item.next_ope]
            if next_op in op_list:
                counters[name] += 1
                if item.pallet == pallet:
                    pos = f'machine_{name}'
                    queue = idx+1 if machine_obj.users else idx
            elif next_op in not_handled_ops:
                counters[f'{name}_s{next_op}'] += 1
                machine_obj_s = res[f'machine_{name}_s']
                if item.pallet == pallet:
                    pos = f'machine_{name}_s{next_op}'
                    queue = idx+1 if machine_obj_s.users else idx

        if machine_obj.users:
            if machine_obj.users[0].pallet.pallet == pallet:
                pos = f'machine_{name}'
                queue = 0
            counters[name] += 1

        machine_s = res.get(f'machine_{name}_s')
        if machine_s and machine_s.users:
            next_op_s = machine_s.users[0].pallet.sequence[machine_s.users[0].pallet.next_ope] ## FIX!
            if machine_s.users[0].pallet.pallet == pallet:
                pos = f'machine_{name}_s{next_op_s}'
                queue = 0
            counters[f'{name}_s{next_op_s}'] += 1

        if name in res['containers_list']:
            container_pals = res.get(f'container_{name}_list', [])
            buffer = res[f'buffer_{name}']
            for idx, container_pal in enumerate(container_pals):
                if container_pal.sequence[container_pal.next_ope] in op_list:
                    counters[name] += 1
                    if container_pal.pallet == pallet:
                        pos =  f'machine_{name}'
                        queue = idx+len(buffer.items)+1 if machine_obj.users else idx+len(buffer.items)
                else:
                    counters[f'{name}_s{container_pal.sequence[container_pal.next_ope]}'] += 1
                    if container_pal.pallet == pallet:
                        pos = f'machine_{name}_s{container_pal.sequence[container_pal.next_ope]}'
                        queue = idx+len(buffer.items)+1 if machine_obj.users else idx+len(buffer.items)

    if  pos == 'machine_3a'or pos == 'machine_3b'or pos == 'machine_3c'or pos == 'machine_2d'or pos == 'machine_1b' or pos == 'machine_2a':
        if time <= 6:
            slot = 1
        else:
            slot = 2

    if pos == 'machine_1a'or pos == 'machine_2b'or pos == 'machine_2c'or pos == 'machine_3d':     
        
        if time <= 8:
            slot = 1 
        else:
            slot = 2


    if pos == 'machine_agent_1' or pos == 'machine_agent_2'or pos == 'machine_agent_3'or pos == 'machine_agent_4':
        if time <= 6:
            slot = 0
        else:
            slot = 1        
    state.update({
        'pos': pos,
        'slot': slot,
        'queue': queue,
        **counters,
        'th_pr': th_pr
    })

    return state

def state_to_tuple(state_dict):
    return tuple(state_dict.items())

# %%
# Configs

def create_configs(res, agent_function_1, agent_function_2, agent_function_3, agent_function_4):
    global config_io, config_agent_1, config_1a, config_1b, config_agent_2, config_agent_3, config_2a, config_2b, config_2c, config_2d, config_3a, config_3b, config_agent_4, config_3c, config_3d, config_quality
    
    config_io = {
        'check_event': res['check_buf_io'],
        'buffer_in': res['buffer_io'],
        'buffer_out': res['buffer_agent_1'],
        'machine': res['machine_io'],
        'machine_s': res['machine_io_s'],
        'machine_ops': machine_io_op,
        'machine_time': machine_time_io,
        'transport_time': transport_time_io_agent_1,
        'io_lag': IO_LAG,
        'name': 'I/O',
        'next_process_func': agent_function_1,
        'next_config': None,
        'check_production_event': res['check_production_event']
    }

    config_agent_1 = {
        'machine_agent': res['machine_agent_1'],
        'buffer_agent': res['buffer_agent_1'],
        'machine_time_agent': MACHINE_TIME_AGENT_1,
        'actions': {
            'up': {
                'transport_time': transport_time_agent1_1a,
                'buffer_out': res['buffer_1a'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_1a'],
                'machine_time_bottleneck': MACHINE_TIME_1A,
                'buffer_bottleneck': res['buffer_1a']
            },
            'down': {
                'transport_time': transport_time_agent1_1b,
                'buffer_out': res['buffer_1b'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_1b'],
                'machine_time_bottleneck': MACHINE_TIME_1B,
                'buffer_bottleneck': res['buffer_1b']
            },
        },
        'container_in': None,
        'priority': ['up', 'down'],
        'check_junction': res['check_junction_1'],
        't_enter_agent': res['t_enter_agent1']
    }

    config_1a = {
        'check_event': res['check_buf_1a'],
        'buffer_in': res['buffer_1a'],
        'buffer_out': res['buffer_agent_2'],
        'machine': res['machine_1a'],
        'machine_s': res['machine_1a_s'],
        'machine_ops': machine_1a_op,
        'machine_time': machine_time_1a,
        'transport_time': transport_time_1a_agent2,
        'name': '1A',
        'next_process_func': agent_function_2,
        'next_config': None,
    }

    config_1b = {
        'check_event': res['check_buf_1b'],
        'buffer_in': res['buffer_1b'],
        'buffer_out': res['buffer_agent_3'],
        'machine': res['machine_1b'],
        'machine_s': res['machine_1b_s'],
        'machine_ops': machine_1b_op,
        'machine_time': machine_time_1b,
        'transport_time': transport_time_1b_agent3,
        'name': '1B',
        'next_process_func': agent_function_3,
        'next_config': None,
    }

    config_agent_2 = {
        'machine_agent': res['machine_agent_2'],
        'buffer_agent': res['buffer_agent_2'],
        'machine_time_agent': MACHINE_TIME_AGENT_2,
        'actions': {
            'up': {
                'transport_time': transport_time_agent2_2a,
                'buffer_out': res['buffer_2a'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_2a'],
                'machine_time_bottleneck': MACHINE_TIME_2A,
                'buffer_bottleneck': res['buffer_2a']
            },
            'down': {
                'transport_time': transport_time_agent2_2b,
                'buffer_out': res['buffer_2b'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_2b'],
                'machine_time_bottleneck': MACHINE_TIME_2B,
                'buffer_bottleneck': res['buffer_2b']
            },
        },
        'container_in': None,
        'priority': ['up', 'down'],
        'check_junction': res['check_junction_2'],
        't_enter_agent': res['t_enter_agent2']
    }

    config_agent_3 = {
        'machine_agent': res['machine_agent_3'],
        'buffer_agent': res['buffer_agent_3'],
        'machine_time_agent': MACHINE_TIME_AGENT_3,
        'actions': {
            'up': {
                'transport_time': transport_time_agent3_2c,
                'buffer_out': res['buffer_2c'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_2c'],
                'machine_time_bottleneck': MACHINE_TIME_2C,
                'buffer_bottleneck': res['buffer_2c']
            },
            'down': {
                'transport_time': transport_time_agent3_2d,
                'buffer_out': res['buffer_2d'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_2d'],
                'machine_time_bottleneck': MACHINE_TIME_2D,
                'buffer_bottleneck': res['buffer_2d']
            },
        },
        'container_in': None,
        'priority': ['up', 'down'],
        'check_junction': res['check_junction_3'],
        't_enter_agent': res['t_enter_agent3']
    }

    config_2a = {
        'check_event': res['check_buf_2a'],
        'buffer_in': res['buffer_2a'],
        'buffer_out': res['buffer_3a'],
        'machine': res['machine_2a'],
        'machine_s': res['machine_2a_s'],
        'machine_ops': machine_2a_op,
        'machine_time': machine_time_2a,
        'transport_time': transport_time_2a_3a,
        'container_out': res['container_3a'],
        'container_out_list': res['container_3a_list'],
        'name': '2A',
        'next_process_func': production_stage_between_junctions,
        'next_config': None,
        'th': {'th_2': {'config_agent': None}},
    }

    config_2b = {
        'check_event': res['check_buf_2b'],
        'buffer_in': res['buffer_2b'],
        'buffer_out': res['buffer_3a'],
        'machine': res['machine_2b'],
        'machine_s': res['machine_2b_s'],
        'machine_ops': machine_2b_op,
        'machine_time': machine_time_2b,
        'transport_time': transport_time_2b_3a,
        'container_out': res['container_3a'],
        'container_out_list': res['container_3a_list'],
        'name': '2B',
        'next_process_func': production_stage_between_junctions,
        'next_config': None,
        'th': {'th_2': {'config_agent': None}},
    }

    config_2c = {
        'check_event': res['check_buf_2c'],
        'buffer_in': res['buffer_2c'],
        'buffer_out': res['buffer_3b'],
        'machine': res['machine_2c'],
        'machine_s': res['machine_2c_s'],
        'machine_ops': machine_2c_op,
        'machine_time': machine_time_2c,
        'transport_time': transport_time_2c_3b,
        'name': '2C',
        'next_process_func': production_stage_before_junction,
        'next_config': None,
    }

    config_2d = {
        'check_event': res['check_buf_2d'],
        'buffer_in': res['buffer_2d'],
        'buffer_out': res['buffer_agent_4'],
        'machine': res['machine_2d'],
        'machine_s': res['machine_2d_s'],
        'machine_ops': machine_2d_op,
        'machine_time': machine_time_2d,
        'transport_time': transport_time_2d_agent4,
        'name': '2D',
        'next_process_func': agent_function_4,
        'next_config': None,
    }

    config_agent_4 = {
        'machine_agent': res['machine_agent_4'],
        'buffer_agent': res['buffer_agent_4'],
        'machine_time_agent': MACHINE_TIME_AGENT_4,
        'actions': {
            'up': {
                'transport_time': transport_time_agent4_3c,
                'buffer_out': res['buffer_3c'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_3c'],
                'machine_time_bottleneck': MACHINE_TIME_3C,
                'buffer_bottleneck': res['buffer_3c']
            },
            'down': {
                'transport_time': transport_time_agent4_3d,
                'buffer_out': res['buffer_3d'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_3d'],
                'machine_time_bottleneck': MACHINE_TIME_3D,
                'buffer_bottleneck': res['buffer_3d']
            },
        },
        'container_in': None,
        'priority': ['up', 'down'],
        'check_junction': res['check_junction_4'],
        't_enter_agent': res['t_enter_agent4']
    }

    config_3a = {
        'check_event': res['check_buf_3a'],
        'buffer_in': res['buffer_3a'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3a'],
        'machine_s': res['machine_3a_s'],
        'machine_ops': machine_3a_op,
        'machine_time': machine_time_3a,
        'transport_time': transport_time_3a_quality,
        'container_in': res['container_3a'],
        'container_in_list': res['container_3a_list'],
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3A',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None}},
    }

    config_3b = {
        'check_event': res['check_buf_3b'],
        'buffer_in': res['buffer_3b'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3b'],
        'machine_s': res['machine_3b_s'],
        'machine_ops': machine_3b_op,
        'machine_time': machine_time_3b,
        'transport_time': transport_time_3b_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3B',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None},
               'th_3': {'config_agent': None}},
    }

    config_3c = {
        'check_event': res['check_buf_3c'],
        'buffer_in': res['buffer_3c'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3c'],
        'machine_s': res['machine_3c_s'],
        'machine_ops': machine_3c_op,
        'machine_time': machine_time_3c,
        'transport_time': transport_time_3c_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3C',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None},
               'th_3': {'config_agent': None},
               'th_4': {'config_agent': None}},
    }

    config_3d = {
        'check_event': res['check_buf_3d'],
        'buffer_in': res['buffer_3d'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3d'],
        'machine_s': res['machine_3d_s'],
        'machine_ops': machine_3d_op,
        'machine_time': machine_time_3d,
        'transport_time': transport_time_3d_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3D',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None},
               'th_3': {'config_agent': None},
               'th_4': {'config_agent': None}},
    } 

    config_quality = {
        'check_event': res['check_buf_quality'],
        'buffer_in': res['buffer_quality'],
        'buffer_out': res['buffer_io'],
        'machine': res['machine_quality'],
        'machine_s': res['machine_quality_s'],
        'machine_ops': machine_quality_op,
        'machine_time': machine_time_quality,
        'transport_time': transport_time_quality_io,
        'container_in': res['container_quality'],
        'container_in_list': res['container_quality_list'],
        'name': 'QUALITY',
        'next_process_func': normal_io,
        'next_config': None,
    }

    config_io['next_config'] = config_agent_1

    config_agent_1['actions']['up']['next_config'] = config_1a
    config_agent_1['actions']['down']['next_config'] = config_1b

    config_1a['next_config'] = config_agent_2
    config_1b['next_config'] = config_agent_3

    config_agent_2['actions']['up']['next_config'] = config_2a
    config_agent_2['actions']['down']['next_config'] = config_2b

    config_agent_3['actions']['up']['next_config'] = config_2c
    config_agent_3['actions']['down']['next_config'] = config_2d

    config_2a['next_config'] = config_3a
    config_2a['th']['th_2']['config_agent'] = config_agent_2

    config_2b['next_config'] = config_3a
    config_2b['th']['th_2']['config_agent'] = config_agent_2

    config_2c['next_config'] = config_3b

    config_2d['next_config'] = config_agent_4
    
    config_agent_4['actions']['up']['next_config'] = config_3c
    config_agent_4['actions']['down']['next_config'] = config_3d

    config_3a['next_config'] = config_quality
    config_3a['th']['th_1']['config_agent'] = config_agent_1

    config_3b['next_config'] = config_quality
    config_3b['th']['th_1']['config_agent'] = config_agent_1
    config_3b['th']['th_3']['config_agent'] = config_agent_3

    config_3c['next_config'] = config_quality
    config_3c['th']['th_1']['config_agent'] = config_agent_1
    config_3c['th']['th_3']['config_agent'] = config_agent_3
    config_3c['th']['th_4']['config_agent'] = config_agent_4

    config_3d['next_config'] = config_quality
    config_3d['th']['th_1']['config_agent'] = config_agent_1
    config_3d['th']['th_3']['config_agent'] = config_agent_3
    config_3d['th']['th_4']['config_agent'] = config_agent_4
    
    config_quality['next_config'] = config_io

# %%
# Source

def source(env, res, agent_function_1, file):
    for i in range(AMOUNT_OF_PRODUCTS):
        t_source = SOURCE_TIME
        yield env.timeout(t_source)
        pallet_type = Pallets_List[i]
        pallet_type.pallet = i+1
        pallet_type.next_ope = 0
        yield res['buffer_agent_1'].put(pallet_type)
        que_agent = agent_function_1(env, res, pallet_type, config_agent_1, file)
        env.process(que_agent)

# %% [markdown]
# # Random Policy

# %%
# Process and Run

counts_random = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs(resources, production_agent_random, production_agent_random, production_agent_random, production_agent_random)
    log_filename = f'RandomPolicy_{seed}.txt'
    f = open(log_filename, 'w')
    env.process(source(env, resources, production_agent_random, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_random.append(resources['pr_count'])
    print('Total Production of Random Policy: ', resources['pr_count'])

# %% [markdown]
# # Heuristic Policy Th

# %%
# Process and Run

counts_heuristic_th = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs(resources, production_agent_heuristic_th, production_agent_heuristic_th, production_agent_heuristic_th, production_agent_heuristic_th)
    log_filename = f'HeuristicPolicyTh_{seed}.txt'
    f = open(log_filename, 'w')
    env.process(source(env, resources, production_agent_heuristic_th, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_heuristic_th.append(resources['pr_count'])
    print('Total Production of Heuristic (for Throughput) Policy: ', resources['pr_count'])

# %% [markdown]
# # Heuristic Policy Flow

# %%
# Process and Run

counts_heuristic_flow = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs(resources, production_agent_heuristic_flow, production_agent_heuristic_flow, production_agent_heuristic_flow, production_agent_heuristic_flow)
    log_filename = f'HeuristicPolicyFlow_{seed}.txt'
    f = open(log_filename, 'w')
    env.process(source(env, resources, production_agent_heuristic_flow, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_heuristic_flow.append(resources['pr_count'])
    print('Total Production of Heuristic (for Flow) Policy: ', resources['pr_count'])

# %% [markdown]
# # RL Agent

# %%
# Q-Table Print Functions

def print_q_table(agent):
    print('Q-table:')
    for (state_key, action), q_value in agent.q_table.items():
        state_dict = dict(state_key)
        state_str = ', '.join([
            f'{k}=\'{v}\'' if k == 'next_ope' else f'{k}={v}'
            for k, v in state_dict.items()
        ])
        print(f'State: ({state_str}), Action: {action} -> Q-value: {q_value:.4f}')

def print_sorted_q_table(agent):
    from collections import defaultdict
    grouped_q = defaultdict(list)

    for (state_key, action), q_value in agent.q_table.items():
        grouped_q[state_key].append((action, q_value))

    sorted_states = sorted(grouped_q.keys(), key=lambda x: tuple((k, str(v)) for k, v in sorted(x)))

    print('Sorted Q-table:')
    for state_key in sorted_states:
        state_dict = dict(state_key)
        state_str = ', '.join([
            f'{k}={v}' for k, v in state_dict.items()
        ])
        print(f'\nState: ({state_str})')

        for action, q_value in sorted(grouped_q[state_key], key=lambda x: x[0]):
            print(f'  Action: {action} -> Q-value: {q_value:.4f}')

# %%
# Agent Function

class QLearningAgent:
    def __init__(self, actions, name, alpha=0.4, gamma=0.99, epsilon=0.1):
        self.q_table = {}
        self.actions = actions
        self.actions_dense = ['wait']
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.name = name
        self.pos = 'machine_' + self.name #.replace('ag_', 'agent_') # Qui prima serviva replace, adesso solo +self.name

    def step_dense(self, new_state, perc):
        reward = TH_P*new_state['th_pr'] - perc*STEP
        return reward

    def choose_action_train(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(self.actions)
        state_key = state_to_tuple(state)
        q_values = [(a, self.q_table.get((state_key, a), 0)) for a in self.actions]
        max_value = max(q_values, key=lambda x: x[1])[1]
        best_actions = [a for a, v in q_values if v == max_value]
        return random.choice(best_actions)

    def choose_action_test(self, state, p=False):
        adjusted_state = dict(state)
        adjusted_state['pos'] = self.pos
        adjusted_state['queue'] = 0
        adjusted_state['slot'] = 0

        if p == True:
            print('Stato Agente Ridotto:', adjusted_state)

        state_key = state_to_tuple(adjusted_state)
        q_values = [(a, self.q_table.get((state_key, a), 0)) for a in self.actions]
        max_value = max(q_values, key=lambda x: x[1])[1]
        best_actions = [a for a, v in q_values if v == max_value]
        
        if p == True:
            print('Azione', self.name, ':', best_actions)

        return random.choice(best_actions)

    def update_agent(self, state, action, reward, new_state, pr=False):
        state_key = state_to_tuple(state)
        new_state_key = state_to_tuple(new_state)

        if pr == True:
            print('')
            print('Stato Iniziale Agente:', state)
            print('Azione:', action)
            print('Q-Value Stato Iniziale Agente:', self.q_table.get((state_key, 'wait'), 0))

        q_predict = self.q_table.get((state_key, action), 0)
        q_target = reward + self.gamma * self.q_table.get((new_state_key, 'wait'), 0)
        self.q_table[(state_key, action)] = q_predict + self.alpha * (q_target - q_predict)
        
        if pr == True:
            print('Stato Finale Agente:', new_state)
            print('Reward:', reward)
            print('Q-Value Stato Finale Agente:', self.q_table.get((new_state_key, 'wait'), 0))
            print('Q-Value Stato Iniziale Agente Aggiornato:', self.q_table[(state_key, action)])

    def update_dense(self, state, action, reward, new_state, pr=False):
        state_key = state_to_tuple(state)
        new_state_key = state_to_tuple(new_state)

        if pr == True:
            print('')
            print('Stato Iniziale Dense:', state)
            print('Azione:', action)
            print('Q-Value Stato Iniziale Dense:', self.q_table.get((state_key, 'wait'), 0))
    
        q_predict = self.q_table.get((state_key, action), 0)
        if new_state[self.name] == 1: # Qui serve la stessa forma dello stato (prima 'ag_1', adesso 'agent_1')
            q_target = reward + self.gamma * max([self.q_table.get((new_state_key, a), 0) for a in self.actions], default=0)
        else:
            q_target = reward + self.gamma * self.q_table.get((new_state_key, 'wait'), 0)
        self.q_table[(state_key, action)] = q_predict + self.alpha * (q_target - q_predict)

        if pr == True:
            print('Stato Finale Dense:', new_state)
            print('Reward:', reward)
            print('Q-Value Stato Finale Dense:', self.q_table.get((new_state_key, 'wait'), 0))
            print('Q-Value Stato Iniziale Dense Aggiornato:', self.q_table[(state_key, action)])

# %%
# Reduced State Function

def reduce_state_train(state, variables,light_on): #TOLTO AUX VAR

# Mandatory variables are always kept
    mandatory_vars = {'pos', 'queue', 'slot'}
    # Normalize input
    variables = set(variables) | mandatory_vars

    # Determine if we should apply the light_on filter
    pos_val = state.get('pos', None)
    apply_light = bool(light_on) and isinstance(light_on, dict) and (pos_val in light_on)

    if apply_light:
        # Allowed-by-light set for this position
        allowed_by_pos = set(light_on.get(pos_val, []))
        # Final keep set: mandatory + (variables ∩ allowed_by_pos)
        keep = mandatory_vars | (variables & allowed_by_pos)
    else:
        # No light_on filtering -> keep requested variables (+ mandatory already merged)
        keep = variables

    # Build reduced state, skipping keys not present in state
    state_reduced = {k: state[k] for k in keep if k in state}
    return state_reduced

def reduce_state_test(state, variables, light_on):

    # Mandatory variables are always kept
    mandatory_vars = {'pos', 'queue', 'slot'}
    # Normalize input
    variables = set(variables) | mandatory_vars

    # Determine if we should apply the light_on filter
    pos_val = "machine_agent_1"
    apply_light = bool(light_on) and isinstance(light_on, dict) and (pos_val in light_on)

    if apply_light:
        # Allowed-by-light set for this position
        allowed_by_pos = set(light_on.get(pos_val, []))
        # Final keep set: mandatory + (variables ∩ allowed_by_pos)
        keep = mandatory_vars | (variables & allowed_by_pos)
    else:
        # No light_on filtering -> keep requested variables (+ mandatory already merged)
        keep = variables

    # Build reduced state, skipping keys not present in state
    state_reduced = {k: state[k] for k in keep if k in state}
    return state_reduced

# %%
# Configs 

agent1_actions = ['up', 'down']
agent1 = QLearningAgent(agent1_actions, 'agent_1')

agent2_actions = ['up', 'down']
agent2 = QLearningAgent(agent2_actions, 'agent_2')

agent3_actions = ['up', 'down']
agent3 = QLearningAgent(agent3_actions, 'agent_3')

agent4_actions = ['up', 'down']
agent4 = QLearningAgent(agent4_actions, 'agent_4')

agents_RL = [agent1, agent2, agent3, agent4]

def create_configs_RL(res, agent1, agent2, agent3, agent4, mode):
    global config_io, config_agent_1, config_1a, config_1b, config_agent_2, config_agent_3, config_2a, config_2b, config_2c, config_2d, config_3a, config_3b, config_agent_4, config_3c, config_3d, config_quality
    
    config_io = {
        'check_event': res['check_buf_io'],
        'buffer_in': res['buffer_io'],
        'buffer_out': res['buffer_agent_1'],
        'machine': res['machine_io'],
        'machine_s': res['machine_io_s'],
        'machine_ops': machine_io_op,
        'machine_time': machine_time_io,
        'transport_time': transport_time_io_agent_1,
        'io_lag': IO_LAG,
        'name': 'I/O',
        'next_process_func': production_agent_RL,
        'next_config': None,
        'check_production_event': res['check_production_event']
    }

    config_agent_1 = {
        'machine_agent': res['machine_agent_1'],
        'buffer_agent': res['buffer_agent_1'],
        'machine_time_agent': MACHINE_TIME_AGENT_1,
        'agent': agent1,
        'mode': mode,
        'actions': {
            'up': {
                'transport_time': transport_time_agent1_1a,
                'buffer_out': res['buffer_1a'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_1a'],
                'machine_time_bottleneck': MACHINE_TIME_1A,
                'buffer_bottleneck': res['buffer_1a']
            },
            'down': {
                'transport_time': transport_time_agent1_1b,
                'buffer_out': res['buffer_1b'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_1b'],
                'machine_time_bottleneck': MACHINE_TIME_1B,
                'buffer_bottleneck': res['buffer_1b']
            },
        },
        'container_in': None,
        'check_agent_in': res['check_agent_1_in'],
        'check_agent_out': res['check_agent_1_out'],
        'check_agent_blocking': res['check_agent_1_blocking'],
        'check_junction': res['check_junction_1'],
        'variables': ['agent_1', 'next_ope_1', '1a', '1b', 'buf_ag_2', 'buf_ag_3', 'buf_ag_1', 'quality', 'th_1','agent_2', '2a', '2b', '3a','agent_3', '2c', '3b', '2d', 'buf_ag_4', 'agent_4', '3c', '3d'],
        'aux_variables': {'bb_2': {'agent_2', '2a', '2b', '3a'},
                          'bb_3': {'agent_3', '2c', '3b', '2d', 'buf_ag_4', 'agent_4', '3c', '3d'}},
        'light_on':  {'machine_1a': {'buf_ag_2','agent_2', '2a', '2b', '3a', 'th_1','agent_1','1a'},
                      'buf_ag_2': {'buf_ag_2','agent_2', '2a', '2b', '3a', 'quality', 'th_1','agent_1'},
                      'machine_agent_2': {'buf_ag_2','agent_2', '2a', '2b', '3a', 'quality', 'th_1','agent_1'},
                      'machine_2a': {'buf_ag_2','agent_2', '2a', '2b', '3a', 'th_1','agent_1'},
                      'machine_2b': {'buf_ag_2','agent_2', '2a', '2b', '3a', 'th_1','agent_1'},
                      'machine_3a': {'buf_ag_2','agent_2', '2a', '2b', '3a', 'th_1','agent_1'},
                      'buf_ag_3': {'buf_ag_3','agent_3', '1b', '2c', '2d','3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_agent_3': {'buf_ag_3','agent_3', '1b', '2c', '2d','3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_1b': { '1b', '2c', '2d','3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_2c': { '2c', '2d','3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_2d': {  '2c', '2d','3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_3b': { '3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'buf_ag_4': {'3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_agent_4': {'3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_3c': {'3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_3d': {'3b','buf_ag_4', 'agent_4', '3c', '3d', 'quality', 'th_1','agent_1'},
                      'machine_quality': {'quality', 'th_1','agent_1'},
                      'machine_agent_1': {'buf_ag_1', 'th_1','agent_1','buf_ag_2', '2a', '2b','buf_ag_3','agent_3', '1b', '2c', '2d','1a','buf_ag_2','agent_2'}
                      },               
        't_enter_agent': 't_enter_agent1'
    }

    config_1a = {
        'check_event': res['check_buf_1a'],
        'buffer_in': res['buffer_1a'],
        'buffer_out': res['buffer_agent_2'],
        'machine': res['machine_1a'],
        'machine_s': res['machine_1a_s'],
        'machine_ops': machine_1a_op,
        'machine_time': machine_time_1a,
        'transport_time': transport_time_1a_agent2,
        'name': '1A',
        'next_process_func': production_agent_RL,
        'next_config': None,
    }

    config_1b = {
        'check_event': res['check_buf_1b'],
        'buffer_in': res['buffer_1b'],
        'buffer_out': res['buffer_agent_3'],
        'machine': res['machine_1b'],
        'machine_s': res['machine_1b_s'],
        'machine_ops': machine_1b_op,
        'machine_time': machine_time_1b,
        'transport_time': transport_time_1b_agent3,
        'name': '1B',
        'next_process_func': production_agent_RL,
        'next_config': None,
    }

    config_agent_2 = {
        'machine_agent': res['machine_agent_2'],
        'buffer_agent': res['buffer_agent_2'],
        'machine_time_agent': MACHINE_TIME_AGENT_2,
        'agent': agent2,
        'mode': mode,
        'actions': {
            'up': {
                'transport_time': transport_time_agent2_2a,
                'buffer_out': res['buffer_2a'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_2a'],
                'machine_time_bottleneck': MACHINE_TIME_2A,
                'buffer_bottleneck': res['buffer_2a']
            },
            'down': {
                'transport_time': transport_time_agent2_2b,
                'buffer_out': res['buffer_2b'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_2b'],
                'machine_time_bottleneck': MACHINE_TIME_2B,
                'buffer_bottleneck': res['buffer_2b']
            },
        },
        'container_in': None,
        'check_agent_in': res['check_agent_2_in'],
        'check_agent_out': res['check_agent_2_out'],
        'check_agent_blocking': res['check_agent_2_blocking'],
        'check_junction': res['check_junction_2'],
        'variables': ['agent_2', 'next_ope_2', '2a', '2b', 'buf_ag_2', '3a', 'th_2'],
        'aux_variables': {},
        'light_on': {},
        't_enter_agent': 't_enter_agent2'
    }

    config_agent_3 = {
        'machine_agent': res['machine_agent_3'],
        'buffer_agent': res['buffer_agent_3'],
        'machine_time_agent': MACHINE_TIME_AGENT_3,
        'agent': agent3,
        'mode': mode,
        'actions': {
            'up': {
                'transport_time': transport_time_agent3_2c,
                'buffer_out': res['buffer_2c'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_2c'],
                'machine_time_bottleneck': MACHINE_TIME_2C,
                'buffer_bottleneck': res['buffer_2c']
            },
            'down': {
                'transport_time': transport_time_agent3_2d,
                'buffer_out': res['buffer_2d'],
                'next_process_func': normal_production_stage,
                'next_config': None,
                'machine_bottleneck': res['machine_2d'],
                'machine_time_bottleneck': MACHINE_TIME_2D,
                'buffer_bottleneck': res['buffer_2d']
            },
        },
        'container_in': None,
        'check_agent_in': res['check_agent_3_in'],
        'check_agent_out': res['check_agent_3_out'],
        'check_agent_blocking': res['check_agent_3_blocking'],
        'check_junction': res['check_junction_3'],
        'variables': ['buf_ag_3', 'agent_3', 'next_ope_3', '2c', '3b', '2d', 'buf_ag_4', 'quality', 'th_3','agent_4', '3c', '3d'],
        'aux_variables': {'bb_4': {'agent_4', '3c', '3d'}},
        'light_on': {},
        't_enter_agent': 't_enter_agent3'
    }

    config_2a = {
        'check_event': res['check_buf_2a'],
        'buffer_in': res['buffer_2a'],
        'buffer_out': res['buffer_3a'],
        'machine': res['machine_2a'],
        'machine_s': res['machine_2a_s'],
        'machine_ops': machine_2a_op,
        'machine_time': machine_time_2a,
        'transport_time': transport_time_2a_3a,
        'container_out': res['container_3a'],
        'container_out_list': res['container_3a_list'],
        'name': '2A',
        'next_process_func': production_stage_between_junctions,
        'next_config': None,
        'th': {'th_2': {'config_agent': None}},
    }

    config_2b = {
        'check_event': res['check_buf_2b'],
        'buffer_in': res['buffer_2b'],
        'buffer_out': res['buffer_3a'],
        'machine': res['machine_2b'],
        'machine_s': res['machine_2b_s'],
        'machine_ops': machine_2b_op,
        'machine_time': machine_time_2b,
        'transport_time': transport_time_2b_3a,
        'container_out': res['container_3a'],
        'container_out_list': res['container_3a_list'],
        'name': '2B',
        'next_process_func': production_stage_between_junctions,
        'next_config': None,
        'th': {'th_2': {'config_agent': None}},
    }

    config_2c = {
        'check_event': res['check_buf_2c'],
        'buffer_in': res['buffer_2c'],
        'buffer_out': res['buffer_3b'],
        'machine': res['machine_2c'],
        'machine_s': res['machine_2c_s'],
        'machine_ops': machine_2c_op,
        'machine_time': machine_time_2c,
        'transport_time': transport_time_2c_3b,
        'name': '2C',
        'next_process_func': production_stage_before_junction,
        'next_config': None,
    }

    config_2d = {
        'check_event': res['check_buf_2d'],
        'buffer_in': res['buffer_2d'],
        'buffer_out': res['buffer_agent_4'],
        'machine': res['machine_2d'],
        'machine_s': res['machine_2d_s'],
        'machine_ops': machine_2d_op,
        'machine_time': machine_time_2d,
        'transport_time': transport_time_2d_agent4,
        'name': '2D',
        'next_process_func': production_agent_RL,
        'next_config': None,
    }

    config_agent_4 = {
        'machine_agent': res['machine_agent_4'],
        'buffer_agent': res['buffer_agent_4'],
        'machine_time_agent': MACHINE_TIME_AGENT_4,
        'agent': agent4,
        'mode': mode,
        'actions': {
            'up': {
                'transport_time': transport_time_agent4_3c,
                'buffer_out': res['buffer_3c'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_3c'],
                'machine_time_bottleneck': MACHINE_TIME_3C,
                'buffer_bottleneck': res['buffer_3c']
            },
            'down': {
                'transport_time': transport_time_agent4_3d,
                'buffer_out': res['buffer_3d'],
                'next_process_func': production_stage_before_junction,
                'next_config': None,
                'machine_bottleneck': res['machine_3d'],
                'machine_time_bottleneck': MACHINE_TIME_3D,
                'buffer_bottleneck': res['buffer_3d']
            },
        },
        'container_in': None,
        'check_agent_in': res['check_agent_4_in'],
        'check_agent_out': res['check_agent_4_out'],
        'check_agent_blocking': res['check_agent_4_blocking'],
        'check_junction': res['check_junction_4'],
        'variables': ['agent_4', 'next_ope_4', '3c', '3d', 'buf_ag_4', 'quality', 'th_4'],
        'aux_variables': {},
        'light_on': {},
        't_enter_agent': 't_enter_agent4'
    }

    config_3a = {
        'check_event': res['check_buf_3a'],
        'buffer_in': res['buffer_3a'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3a'],
        'machine_s': res['machine_3a_s'],
        'machine_ops': machine_3a_op,
        'machine_time': machine_time_3a,
        'transport_time': transport_time_3a_quality,
        'container_in': res['container_3a'],
        'container_in_list': res['container_3a_list'],
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3A',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None}},
    }

    config_3b = {
        'check_event': res['check_buf_3b'],
        'buffer_in': res['buffer_3b'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3b'],
        'machine_s': res['machine_3b_s'],
        'machine_ops': machine_3b_op,
        'machine_time': machine_time_3b,
        'transport_time': transport_time_3b_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3B',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None},
               'th_3': {'config_agent': None}},
    }

    config_3c = {
        'check_event': res['check_buf_3c'],
        'buffer_in': res['buffer_3c'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3c'],
        'machine_s': res['machine_3c_s'],
        'machine_ops': machine_3c_op,
        'machine_time': machine_time_3c,
        'transport_time': transport_time_3c_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3C',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None},
               'th_3': {'config_agent': None},
               'th_4': {'config_agent': None}},
    }

    config_3d = {
        'check_event': res['check_buf_3d'],
        'buffer_in': res['buffer_3d'],
        'buffer_out': res['buffer_quality'],
        'machine': res['machine_3d'],
        'machine_s': res['machine_3d_s'],
        'machine_ops': machine_3d_op,
        'machine_time': machine_time_3d,
        'transport_time': transport_time_3d_quality,
        'container_out': res['container_quality'],
        'container_out_list': res['container_quality_list'],
        'name': '3D',
        'next_process_func': production_stage_after_junction,
        'next_config': None,
        'th': {'th_1': {'config_agent': None},
               'th_3': {'config_agent': None},
               'th_4': {'config_agent': None}},
    } 

    config_quality = {
        'check_event': res['check_buf_quality'],
        'buffer_in': res['buffer_quality'],
        'buffer_out': res['buffer_io'],
        'machine': res['machine_quality'],
        'machine_s': res['machine_quality_s'],
        'machine_ops': machine_quality_op,
        'machine_time': machine_time_quality,
        'transport_time': transport_time_quality_io,
        'container_in': res['container_quality'],
        'container_in_list': res['container_quality_list'],
        'name': 'QUALITY',
        'next_process_func': normal_io,
        'next_config': None,
    }

    config_io['next_config'] = config_agent_1

    config_agent_1['actions']['up']['next_config'] = config_1a
    config_agent_1['actions']['down']['next_config'] = config_1b

    config_1a['next_config'] = config_agent_2
    config_1b['next_config'] = config_agent_3

    config_agent_2['actions']['up']['next_config'] = config_2a
    config_agent_2['actions']['down']['next_config'] = config_2b

    config_agent_3['actions']['up']['next_config'] = config_2c
    config_agent_3['actions']['down']['next_config'] = config_2d

    config_2a['next_config'] = config_3a
    config_2a['th']['th_2']['config_agent'] = config_agent_2

    config_2b['next_config'] = config_3a
    config_2b['th']['th_2']['config_agent'] = config_agent_2

    config_2c['next_config'] = config_3b

    config_2d['next_config'] = config_agent_4
    
    config_agent_4['actions']['up']['next_config'] = config_3c
    config_agent_4['actions']['down']['next_config'] = config_3d

    config_3a['next_config'] = config_quality
    config_3a['th']['th_1']['config_agent'] = config_agent_1

    config_3b['next_config'] = config_quality
    config_3b['th']['th_1']['config_agent'] = config_agent_1
    config_3b['th']['th_3']['config_agent'] = config_agent_3

    config_3c['next_config'] = config_quality
    config_3c['th']['th_1']['config_agent'] = config_agent_1
    config_3c['th']['th_3']['config_agent'] = config_agent_3
    config_3c['th']['th_4']['config_agent'] = config_agent_4

    config_3d['next_config'] = config_quality
    config_3d['th']['th_1']['config_agent'] = config_agent_1
    config_3d['th']['th_3']['config_agent'] = config_agent_3
    config_3d['th']['th_4']['config_agent'] = config_agent_4
    
    config_quality['next_config'] = config_io

# %% [markdown]
# ## Training

# %%
# Source Training

def source_train_RL(env, res, file):
    for i in range(AMOUNT_OF_PRODUCTS):
        t_source = SOURCE_TIME
        yield env.timeout(t_source)
        pallet_type = Pallets_List[i]
        pallet_type.pallet = i+1
        pallet_type.next_ope = 0
        yield res['buffer_agent_1'].put(pallet_type)
        que_agent = production_agent_RL(env, res, pallet_type, config_agent_1, file, train=True)
        env.process(que_agent)
    
    env.process(rl_dense(env, res, T_STEP, T_START, config_agent_1, 'th_1',pr=True))
    env.process(rl_dense(env, res, T_STEP, T_START, config_agent_2, 'th_2'))
    env.process(rl_dense(env, res, T_STEP, T_START, config_agent_3, 'th_3'))
    env.process(rl_dense(env, res, T_STEP, T_START, config_agent_4, 'th_4'))

def rl_dense(env, res, t_sampling, t_start, config_agent, th_code, pr=False):
    if env.now < t_start:
        yield env.timeout(t_start - env.now)

    yield config_agent['check_agent_out']
    while True:
        action = 'wait'
        state = get_state(env, res, PALLET_STAR)
        #reduced_state = reduce_state_train(state, config_agent['variables'], config_agent['aux_variables'])
        reduced_state = reduce_state_train(state, config_agent['variables'],config_agent['light_on'])

        clock = env.now
        yield AnyOf(env, [env.timeout(t_sampling), config_agent['check_junction']])
        clock = (env.now - clock)/t_sampling
        new_state = get_state(env, res, PALLET_STAR)
        #new_reduced_state = reduce_state_train(new_state, config_agent['variables'], config_agent['aux_variables'])
        new_reduced_state = reduce_state_train(new_state, config_agent['variables'],config_agent['light_on'])

        reward = TH_P*new_reduced_state[th_code] - clock*STEP
        if config_agent['agent'] == agent1:
            config_agent['agent'].update_agent(reduced_state, action, reward, new_reduced_state,pr=False)
        else:
            config_agent['agent'].update_agent(reduced_state, action, reward, new_reduced_state)

        if new_reduced_state[th_code] == 1:
            yield config_agent['check_agent_out']

# %%
# Process and Run

seed_list_training = [1]
counts_training = []

for seed in seed_list_training:
    random.seed(seed)
    env, resources = create_environment()
    create_configs_RL(resources, agent1, agent2, agent3, agent4, 'train')
    log_filename = f'RLTraining_{seed}.txt'
    f = open(log_filename, 'w')
    env.process(source_train_RL(env, resources, f))
    env.run(until=SIMULATION_LENGTH*12.5)
    f.close()
    counts_training.append(resources['pr_count'])
    print('Total Production of RL (Training): ', resources['pr_count'])

# %%
# Print Q-Table

for idx, ag in enumerate(agents_RL):
    print('Agent', idx+1)
    print_q_table(ag)
    print('')
    print('')

# %%
# Print Sorted Q-Table

for idx, ag in enumerate(agents_RL):
    print('Agent', idx+1)
    print_sorted_q_table(ag)
    print('')
    print('')

# %%
print('Agent 1:')
print_sorted_q_table(agent1)

# %%
print('Agent 2:')
print_sorted_q_table(agent2)
print('')
print('Agent 4:')
print_sorted_q_table(agent4)

# %%
print('Agent 3:')
print_sorted_q_table(agent3)

# %%
print('Agent 4:')
print_sorted_q_table(agent4)

# %% [markdown]
# ## Test

# %%
# Process and Run

counts_test = []

for seed in seed_list:
    random.seed(seed)
    env, resources = create_environment()
    create_configs_RL(resources, agent1, agent2, agent3, agent4, 'test')
    log_filename = f'RLTest_{seed}.txt'
    f = open(log_filename, 'w')
    env.process(source(env, resources, production_agent_RL, f))
    env.run(until=SIMULATION_LENGTH)
    f.close()
    counts_test.append(resources['pr_count'])
    print('Total Production of RL (Test): ', resources['pr_count'])
